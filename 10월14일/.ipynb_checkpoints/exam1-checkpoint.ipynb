# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)
# Out:
# 3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]

# %%
import os
print(os.getcwd())
# Out:
# c:\PyStexam

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   pydatavenv    C:\Users\Minyoung Kim\AppData\Roaming\jupyter\kernels\pydatavenv
#   python3       C:\Users\Minyoung Kim\anaconda3\share\jupyter\kernels\python3

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Wed, 14 Oct 2020 06:26:15 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=b607fb619098563191bca2ce1326abec1da48e8acfc7450639c079660d394ae0; Expires=Thu, 15 Oct 2020 06:26:15 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x000001E409D82B08>
# [ header 정보 ]----------
# ('Date', 'Wed, 14 Oct 2020 05:25:56 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.aladin.co.kr/home/welcome.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-
# ===========================================================
# https://www.aladin.co.kr/home/welcome.aspx  페이지의 인코딩 정보 : utf-8
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" >
# <html>
#   <head>
#       <title id="Title">알라딘</title>
#       <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
# 	  <meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR">
# 	  <meta content="C#" name="CODE_LANGUAGE">
# 	  <meta content="JavaScript" name="vs_defaultClientScript">
# 	  <meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema">
#       <meta http-equiv="
# ===========================================================

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ URL 문자열 정보 추출 1 ]
# 타입정보 :  <class 'urllib.parse.ParseResult'>
# 도메인정보 :  movie.daum.net
# 패스정보 :  /moviedb/main
# 쿼리정보 :  movieId=93252
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :
# URL 문자열정보 :  https://movie.daum.net/moviedb/main?movieId=93252
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='movie.daum.net', path='/moviedb/main', params='', query='movieId=93252', fragment='')
#
# [ URL 문자열 정보 추출 2 ]
# 도메인정보 :  docs.python.org
# 패스정보 :  /3/library/urllib.parse.html
# 쿼리정보 :
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :  urlparse-result-object
# URL 문자열정보 :  https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='docs.python.org', path='/3/library/urllib.parse.html', params='', query='', fragment='urlparse-result-object')
#
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
# get방식
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
# post방식 1
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
# post방식 2
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
## header정보만 가져옴
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers) # header만 읽기
if r.text :  # body읽어오기
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 14 Oct 2020 06:06:41 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '164', 'Connection': 'close', 'Content-Type': 'text/html'}
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 14 Oct 2020 06:08:43 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Connection': 'close', 'Content-Type': 'text/html'}
# 응답된 콘텐츠가 없어요

# %%
#파일명 : exam3_11.py
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')] # 튜플 리스트
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
## 사진 가져오기
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content)) # binary형식을 불러올때는 comtent 사용해야함
print(type(i))
i.save("c:/Temp/test.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify()) # 그냥 출력하는것 보다 이쁘게 나옴
print(bs)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>
#
#
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Test BeautifulSoup</title>
# </head>
# <body>
# <p align="center">P태그의 컨텐트</p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
# </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.string)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
# Out:
# [ string 속성 ]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [ text 속성 ]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> : None
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [ contents 속성 ]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : None
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))  # dictionary로도 가능
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
    print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6]
    content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 담보
# 평점 : 10
# 리뷰글 : 어린시절이 생각나서 초반부터 울면서봤어요..진짜감동적이고 재밋어요~~~
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 9
# 리뷰글 : 어두운 내용과 대비되는 따뜻한 색채감. 미쟝센 너무 좋다. 세상에 소외된 혹은 상처받은 사람들의 기묘한 유대감. 모호한 분위기와 뻔하지 않은 결말이 생각할 거리를 줘서 좋았어요.
# -----------------------------------------
# 영화 제목 : 퍼펙트 게임
# 평점 : 10
# 리뷰글 : 우리나라 스포츠의 감동을 느낄 수 있습니다
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 1
# 리뷰글 : 평점 주신분들이 영화를 안보셨나봐요대체적으로 연기는 좋았으나 내용은 너무 이해 안가게 중구난방이었음영화 끝나자마자 같이간 친구한테 이게 뭐야라고 했더니 그러게 말이야를 주고 받으며 나옴
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 3
# 리뷰글 : 유아인 배우의 연기는 좋은데.. 영화 자체가 별로라...
# -----------------------------------------
# 영화 제목 : 먼 훗날 우리
# 평점 : 10
# 리뷰글 : 엔딩크레딧에서 감동을 더해주네요 참 좋은 영화입니다.
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 10
# 리뷰글 : 배우들 연기와 영화 분위기는 지린다 진심
# -----------------------------------------
# 영화 제목 : 돌멩이
# 평점 : 2
# 리뷰글 : 감동은 있는데 결말,,,여운이남네ㅋㅋㅋㅋ그냥 딴영화보는게 맘편할듯
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 10
# 리뷰글 : 대사없이 이런 연기가 가능하다니;
# -----------------------------------------
# 영화 제목 : 소리도 없이
# 평점 : 10
# 리뷰글 : 연기 역시 최고네요ㅠ 기대했던 영환데 너무 재밌게 봤어요!!
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("신고", '', content)
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + "\t"+movie_title[i]+"\t"+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 6	우리들의 일기	수호는 에이전트H와 닮았다.
# 8	돌멩이	생각할 거리를 던져주는 영화인 것 같아요. 그게 어찌보면 좀 답답하고 찝찝한 기분으로 다가올 수 있지만, 오랜만에 혼자 이런 저런 생각하며 스스로를 돌아볼 수 있는 좋은 시간이었던 것 같아요.
# 5	뮬란	일그러진 PC가 망친 또 하나의 작품. 입체성을 잃은 뮬란은 양산형 무협지의 흔한 천재 주인공으로 전락했고, 모든 주변 인들은 단지 성별에 매여 타고난 천재의 앞길을 가로막는 어리석은 장님들이 되어버렸다. 디즈니는 무엇이 과거의 명작을 만들었는지 다시 돌아봐야만 한다.
# 10	죽지않는 인간들의 밤	깨알재미~잼있어요 양동근님 ㅋㅋ 너무 웃겨 죽는줄
# 10	돌멩이	정말 석구의 삶을 보니 먹먹해지더라고요..그 와중에 우리 삶을 포기하지않고 지켜주시는 분이 생각났습니다.. 너무나 깊은 울림이 있는영화감사합니다 ㅜㅜ 재미있게봤습니다!!^^
# 10	에브리타임 룩 앳 유	독일판 비포선라이즈같은 영화.개인적으로 이 영화가 더 좋네요.마음이 간질간질,몽글몽글해지는 영화.다른 독일 영화도 보고싶어지네요.
# 8	죽지않는 인간들의 밤	호불호가 있는 영화 .병맛 좋아하면 추천.. 후반부 양동근 나올때마다 피식피식 웃엇어요 ㅎ
# 6	애프터: 그 후	1의 느낌이 더 좋았습니다.
# 2	폰조	범죄자 치매 걸린 영화는 도대체 왜 만드는건지.배우들의 연기력을 논하기조차 귀찮은 영화.영화보다가 30분간이상 자긴 첨이네요.
# 10	미녀는 괴로워	20대 초반에 영화를 보고 30대 중반에 영화를 다시보니 정말 잘 만든 영화라는 생각이 드네요. 못보신분들은 꼭 보시길 추천 드립니다.
# -----------------------------------------------------
# 1	죽지않는 인간들의 밤	B급 영화지만 B급영화의 참신함이 없다.화면전환없이 계속되는 지루한 연출,내용흐름 방해하는 쓸데없는 장면,후반에 가니 배우들 연기들까지 싫어진다.대한민국에 눈먼 자본이 많다는걸 이 영화로 다시 확인했다.
# 1	소리도 없이	설정마저도 진부하다.
# 10	철없는 아내와 파란만장한 남편, 그리고 태권소녀	앞서간 영화..연기등등 너무 재미있고 좋았어요
# 1	강철비2: 정상회담	여기가 북한인가??? 진짜 간첩들 미쳐 날뛰네 이정권에서 정말 아무것도 모르는 애들한테 무슨 사상을 주입하려고?? 아진짜 대한민국 답없이 가네...
# 10	소리도 없이	너무 기대되는 영화에요! 꼭 극장에서 보겠음~ ^^
# 10	겨울왕국 2	그냥 완벽합니다. 그래서 시즌3 언제 나온다고요?
# 10	나의 이름	전소민 연기존잘함..!! 눈빛 연기에 반함
# 2	폰조	진짜 개지루하다. 톰하디 분장, 연기 빼고 이렇게 거지같은건 올해 반도 이후 두번째
# 2	폰조	감독이 최악의 감독상 받았다는 뉴스를 봤는데 그 이유를 알겠다. 내인생 최악의 영화 탑3 안에 들어간다. 톰하디로도 커버 자체가 불가능함.
# 6	아웃포스트	후반 전투 장면의 몰입도는 높다. 하지만 감독의 연출이 산만하고 병사들 잡담이 많다..
# -----------------------------------------------------
# 10	보랏 - 카자흐스탄 킹카의 미국 문화 빨아들이기	이런게 코미디 영화지 사랑해요 보랏
# 8	극장판 미니특공대: 햄버거괴물의 습격	4살 애기가 잼있다고 하네요~
# 10	50가지 그림자: 해방	이걸 왜 이제야 봤을까요...ㅠㅠ 정말 연애세포가 깨어나네요..넘 재밌어요!!!
# 8	버티고
# 10	악마는 사라지지 않는다	영화에서 나오는 교회가 워킹데드2 1화에 나오는 교회랑  같은 곳이군요
# 10	백조 공주
# 6	돌멩이	생각외로 괜찮음 그냥 딱 그정도
# 10	행복	임수정이 "같이 살래요? " 했을 때 남성관객들의 심쿵..
# 6	매치 포인트	야망으로 가득찬 남자의 성공기. 비도덕적이지만 매력적이다. 주인공이 몰락하지 않는 마지막도 좋았다.
# 10	소리도 없이	영화에 비해 평점이 너무 낮네요...
# -----------------------------------------------------
# 10	이프 온리	제 인생 최고의 영화들 중에 반드시 한 자리를 차지해야 하는 영화
# 10	프록시마 프로젝트	에바 그린 출연 작품들 중 제일 좋았던 작품ㅠㅠ 쌀쌀해진 날씨에 넘 딱 어울리는 선택이었다
# 1	담보
# 10	남자가 사랑할 때	최고 여운이 계속 남는 영화
# 1	뮬란	그냥 알라딘처럼 원작처럼만 하면 되었을것을..왜.. 노래 용 다 없애가며...
# 10	소리도 없이	유아인 대사 없는데 분위기랑 연기 지렸다
# 10	프록시마 프로젝트	오랜만에 연출, 연기  다 좋은 영화본 것 같아요.  마음이 따뜻해져서 추천하고 싶어요!
# 10	프록시마 프로젝트	너무 감동적인 영화 특히나 배우의 연기가 몰입감을 더했음
# 10	의뢰인	특히 장혁의 연기가 지리는 영화
# 10	프록시마 프로젝트	기대 안하고 봤는데,, 너무 완성도 있어서 놀람... 특히 배우 연기 굿!
# -----------------------------------------------------
# 8	퀸카가 아니어도 좋아	생각보다 너무 재밌었음ㅋㅋㅋ
# 8	그리드	별생각 안하고 갔다가 뒷통수 세게 맞고 나온 영화. 들고 있던 쇼핑백이 무거워진 순간. 오랜만에 재밌게 봤다.
# 10	프록시마 프로젝트	배우들 연기가 너무 좋았고, 오랜만에 마음이 따뜻해지는 영화였다
# 10	프록시마 프로젝트	일과 가정 둘 다 사랑하는 사람의 고민을 너무 잘 표현한ㅠㅠ 사랑하는 가족이 있는 직장인들은 백번 공감할 영화
# 9	해적: 바다로 간 산적
# 10	소리도 없이	유아인♡믿고 보러간다.
# 9	유전
# 9	소리도 없이	이 시국에도 저번주 시사회로 이 영화 본 사람들 있다. 자기가 극장 가기 싫어서 안가면 그만이지 1점 평점 테러는 왜 하는데? 배우 연기와 영상미는 뛰어났다. 평점 테러하지마라
# 10	소리도 없이	연출ㅡ감동 지수 높음 별 5개
# 10	프록시마 프로젝트	날씨 추워지는데 마음이 따뜻해지는 영화였음..ㅠ 올해 본 영화 중 손에 꼽을만큼 너무 좋았다
# -----------------------------------------------------
# 10	클레멘타인	K-영화의 OO점이 된 영화
# 6	더 로드	생활이 무너지면 사람이 무너지고 사람이 무너지면 철학이 무너진다.재난 영화가 아닌 신념에 관한 질문을 던지는 영화그러나 신념조차 아이의 눈으로 규정하는 불편한 영화?인간은 왜 착해야 하는가
# 10	덕구	진짜 너무 재밌게봤어요 배우님들 건강하세요!!
# 1	소리도 없이	이 시국에 영화관을 왜 가?
# 8	담보	배우들이 하나같이 너무 연기를 잘해서 감동적이고 재밌었습니다.
# 10	담보
# 10	마이 시스터즈 키퍼	가족을 생각하게 하는눈물을 펑펑 울리게 만드는 영화입니다
# 4	폰조	악명높은 시카고 마피아 두목 알 카포네의 마지막 1년을 그리는 데, 치매와 매독, 뇌졸증을 앓던 알 카포네의 환각과 후회, 망상으로 불안하고 혼란스런 정신세계를 방문한 기분
# 1	폰조	봆짒맚셊욦냆값뭢봢짒?
# 10	원스 어폰 어 타임... 인 할리우드	그의 마지막 영화가 기대된다.
# -----------------------------------------------------
# 9	그리드	신랄한 풍자와 그 이면. 달콤하면서도 씁쓸한.
# 10	너의 이름은.	딸아이와 두번째 관람이였습니다.다시 보고싶어서 항상 기다렸는데,, 상영된다는 소식에 ^^스토리, 영상, OST 모두 만족스러워요
# 1	뮬란	귀뚜라미랑 무슈 없는 것도 아쉽고 마녀가 나오는것도 이상하고.... 평점이 8.1?
# 10	해리 포터와 마법사의 돌
# 2	뮬란	전형적인 짜장면 묻는 영화. 정작 중국시장 흥행 실패 풉ㅋ
# 10	에놀라 홈즈
# 10	미쓰백
# 10	소리도 없이	안 봤지만 유아인 사랑해요
# 10	폰조	톰하디의 연기 굿굿~~
# 10	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	봐도 봐도 자꾸 생각나는 마법같은 영상
# -----------------------------------------------------
# 1	#살아있다	아.이.재.밌.다하 현타온다
# 10	정도	마지막 ost나오는데 너무좋았어요.2편 기다려져요.
# 7	극장판 원피스 스탬피드
# 2	폰조	톰하디 연기말곤 볼게 없는 최악의 영화....ㅠ
# 7	닥터 두리틀
# 10	소공녀	인생영화
# 10	나의 특별한 형제
# 10	말죽거리 잔혹사	Tv 채널 돌리다가 하고있으면 무조건 보게되는영화특징 : 잠깐볼라고 했는데 엔딩까지봄
# 1	기기괴괴 성형수	ㅎ....제발 원작 망치는 짓은 그만 좀 합시다.
# 1	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	왜 원정도박은 없죠????
# -----------------------------------------------------
# 10	다시 만난 날들	유튜브 알고리즘이 기타배틀씬 영상을 알려줘서 이 영화를 알게되었고 찾아보니 아직 상영중이길래 다음날 바로 보고옴..조금 지루하고(전체적으로 잔잔하고 편집이 늘어지는 부분이 살짝 있긴함. 그래도 웃음 포인트도 많음..) 아주아주 많이 사랑스러운 영화. 특히 중딩밴드 실력 오지고 넘나 귀여움!! 평소 기타를 좋아해서 장하은님 때문에 알고리즘이 알려줬나 싶었는데 알고보니 홍이삭님이 주연배우여서 더 좋았던..슈퍼밴드 출신 카메오들 찾아보는 재미도 쏠쏠함.
# 10	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	김호중의 진심과 팬들을 위하는 마음 노래에 대한진정성을 알 수 있었다여운이 깊이 남는 영화다
# 10	블랙핑크: 세상을 밝혀라	로제의 작사, 작곡의 솔로곡을 기대하게 된다. 4명 모두 멋지다. 롱런하길 바란다.
# 10	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	김호중 노래하는 사람의 진정성팬들과 만드어낸 아름다운 스토리웅장한 무대연출 보고 또 봐도 보고 싶고 듣고 싶은 영화
# 10	교실 안의 야크	영혼이 맑아지는 영화..'나그네와 마술사' 이후 부탄여행 동기부여 2탄~범죄영화는 이제그만~ 만들어주시고 ..이런영화늘 원합니다.
# 2	미드소마	감독의 색깔만 뚜렷함  그리고 기괴하기만함 공포영화라지만 공포 1안느껴짐 마약하는 단체 사이코 단체 다큐 느낌
# 2	폰조	영화 시작 1시간 내 최소 5명 나가는 영화, 조커 제작진이 만들었다고 해서 기대했는데 와장창 깨뜨리고 잔인한 장면은 차라리 넣지 말던가, 당근씹는 좀비 톰하디 연기력만 보이는 영화
# 10	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	별님의 목소리에 감동 받으며 시간이 어떻게 흘러 갔는지 모르게 영화가 끝났습니다. 재 관람 시에도 같은 감동을 느끼며 영화를 관람했습니다. 종영 전 한번 더 볼 예정입니다. 별님=감동.
# 1	82년생 김지영	네이버에 페미가 많긴 많구나... 평론가란 작자들도 현실구분 못하고 고평점 주는거 보니 ㅋㅋㅋ 거기다 두명 빼고 여자임 ㅋㅋㅋ 도대체 무슨 기준으로 평론가 뽑는걸까?? ㅋㅋㅋ꼴페미면 바로 평론가 되나?? ㅋㅋ 뭐 여튼 다음은 6점대 인데 네이바는 9점대네 ㅋㅋ 다음이 그나마 쿵쾅 꼴페미들 유입이 적나보다
# 4	폰조	판타스틱4 감독한테 뭘 바람?
# -----------------------------------------------------
# 10	부활: 그 증거	"내가 죽은 뒤 어떻게 될 지"가 지금 당장 죽어도 될 만큼 확실한 사람이 아니라면... 봐야 한다.
# 10	디파이언스	동부전선 파르티잔 이야기라 해서 봤는데 재밌음 ㅋㅋ
# 4	언힌지드	미쿡에선 경찰이 별로 없나봐요
# 8	스파이 지니어스
# 7	봉오동 전투	남자들을 위한 영화. 영웅 만들기 영화. 하지만 역사가 있는 영화. 미안하지만 2번은 안 볼 영화.
# 6	다만 악에서 구하소서	배우 연기야 이미 검증된 배우들인데 스토리가 너무 진부함.
# 8	남자가 사랑할 때	한 남자가 한 여자에 대한 사랑을 시작하고 마무리하는 과정을 그린 영화. 억지스러운 스토리가 있지만 황정민이기에 용서가 된다는 점.
# 10	태극기 휘날리며	엄마아빠도 봤던영환데내가 자주봤습니다 재밌더라고요 마지막장면 재밌어요 연기 잘하네요 ㅇㅇ  내가 어떨때 보냐먼 심심하거나한가할때 봐요
# 1	봉오동 전투	대한민국의 독립 : 봉오동전투가 아니라 미국의 태평양전쟁 승전으로 얻어짐, 대한민국의 자유 : 공산당의 기습 침략을 미국의 참전으로 막아냄 (대한민국의 가치는 투철한 자유민주주의에 있음 독립운동 백번을 했어도 공산주의자 사회주의자였다면 배제해야함)
# 9	남과 여	남자와 여자가 사랑하게 되는 과정을 잘 그려준 영화. 처음에 사랑하게 되는 과정은 이해되지 않았지만 사랑하게 된후의 감정선은 잘 그려진 것 같다. 두 사람의 눈물의 의미가 이해되어 슬펐다.
# -----------------------------------------------------
# 8	언힌지드	킬링타임으로 좋으나감독이 경찰 안티인듯
# 8	안녕까지 30분	스토리가 매력이잇네요
# 6	21	무난하다...
# 10	실미도	실화가 더 처참해 영화에 다 못담은
# 10	인어 공주
# 10	투사부일체	14년이 지난 지금봐도 재밋는데 평점 말안된다 생각하고 요즘엔 이런영화가 안나와서 아쉽다
# 10	담보	연기 너무너무 모두 좋아요
# 1	폰조	내가 이거 다시보믄 사람이 아니다 진찐
# 10	에놀라 홈즈	재밌어요~ 속편 나왔으면 좋겠네요!
# 1	뮬란	에니메이션 보다 못한 영화를 만들 수 있다니 참 대단하다
# -----------------------------------------------------
# 10	82년생 김지영
# 8	로드 투 퍼디션
# 5	윈드 리버	중후반까지 너무 지루... 이후에 갑자기 전개됨. FBI 요원은 능력이 너무 없음. 남주가 FBI 보다 훨씬 나음.
# 10	애프터: 그 후	음.. 저 고3인데.. 음..ㅎㅎ.. 많이 ㅇㅑ하네요
# 5	돈 크라이 마미	어떤실화를 기본으로했는지 모르겠지만,  성폭당한 학생이 자살을했는데 경찰이  아무것도안하고  손놓고있는게 말이되나?   그리고 딸이 두번째성폭을 당하고왔는데 엄마는 왜모르는척을하지?
# 1	죽지않는 인간들의 밤	감독이 얼마나 개멍청한지 음주측정을 아직 빨대입에 물고 하는줄 아는 저 정신머리  보소..주민번호는 남자가  2로 시작하니? 아휴..졸라 연출부 멍청하노?아무리 웃기고 싶어서 드립쳐도 그렇지 경찰이 생년월일 물어보고 생긴걸로 비하하고.. 생각이란게 있냐?정신오라가락하는 노숙자를 타경찰서인계하는데 그걸 경찰 지들이 안하고 일반인들에게 맡긴다고?알밥 색들 직이뿔라.이미도는 재미도 읍고 날이 갈 수록 개비호감이고?
# 1	간신	쓸떼없는 장면들을 위해 그렇게 많은 여자들이 벗고 더럽혀지고남자들 눈호강하고 마음껏 자위하라고 만든 불쾌한 쓰레기 영화.(감상포인트 없는데 자꾸 누르래 ㅈㄴ빡치게)
# 10	소원	조두순은사건은 진짜 피해자분들이 안타까운 사건임...  조두순 그 짐승같은 미친놈은 사형당해야 되는데 말도 안 되는 법 때문에 12년형 받고...  와... 조두순면상만 봐도 진짜 조두순을 조저버리고싶다라는 생각이 든다... 피해자분들께서 힘을 낼 수 없는 상황이란걸 알지만 최대한 힘을 내셔서 조두순을 이기고 할 수 있는만큼 최대로 행복하고 화목하게 사셨으면 좋겠다.
# 10	담보	소이 때문에 영화 보는내내 웃고 울고 했다... 너무너무 재미있게 잘봤다...
# 8	담보	평점 9점대길래 정말 많은 기대를 하고 봤는데 그정도까진 아닌듯초반까지 짜임세 있는 구성이 후반으로 갈 수록 힘이 빠지는 것이 느껴짐...볼 만했던 건 아역배우 너무 이쁘고 연기도 잘하는 거랑 갓지원님 미모..
# -----------------------------------------------------
# 8	밤치기	내 안의 상도덕은 이 영화를 불편하다고 받아들이는 것 같은데 묘하게 끌어당기는 것이 꼭 마수 같아서 흥미롭게 봤다. 특히 박종환 배우가 너무 안정감 있었다.
# 10	너와 파도를 탈 수 있다면	보고나서 소중한 사람을 잃게 된다면 ...라는 생각이 드네요 ㅠㅠ
# 9	파리의 딜릴리	꼴라주식 연출에 박수를.. 애니메이션 캐릭터와 실사배경을 접목시켜 화면을 수놓듯 배치했는데 아름다웠다. 이렇게 영화만이 낼 수 있는 독특한 연출들을 감독들이 이용해주면 관람자 입장에서는 감사하다.. 움직이는 미술관을 보는것 같아서. 당대 최고의 예술가들 모네, 르누아르, 피카소, 사라 베르나르, 툴루즈로트렉 등을 만나고 거쳐가며 스토리가 전개되는데 내가 그들을 만나는 여행을 하는듯 설렜다. 인종차별과 여성인권이라는 아프고 무거운 주제를 딜릴리를 통해 따뜻하고 재기발랄하게 담아낸 좋은 영화
# 3	부활: 그 증거	현대 기독교 사람들은 아우구스티누스나 마틴로이드존스나 조나단에드워즈같은 역사의 거대신학자들을 좋아한다고 말하면서 그와 전혀 매치가 안되는 사람들이 그와 다른 줄도 모르고 받아들인다. 단지 읽는 게 문제라는 게 아니라 1.이런 저런 걸 걸러 듣는 것도 아니고 2.아니다 그게 아니고 이게 맞다의 자기주관이 있는 것도 아니고 *그냥 완전한 신학실종상태다 지금은 논리잃은 혼종들의 종교시대 즉 정체성 없는 종교의 시대 라고 보면 정확함. 여기서 내려놓음같은 게 왜 나옴
# 5	폰조	폰 누가 뺏어갔냐 폰조라 빨리
# 10	플랜맨	걍 한지민 땜에 끝까지 봄ㅋ
# 8	더 씽	적당한 긴장감과 적당히 징그러운 크리쳐. 중구난방 감염보다는 누가 진짜인지의 촛점을 맞추는 추리 부분에 분량을 추가했으면 쫄깃함이 더 했을텐데. 꽤 볼 만 하긴하다.
# 7	천장지구 3 - 천장지구 완결	관지림 황비홍 이모
# 10	계춘할망	힐링 가족 풍광 인생 의미
# 7	언더월드 - 라이칸의 반란	비급영화=몇UBD?
# -----------------------------------------------------
# 6	이웃의 아내	옆집노인의주거침입으로 인해 자기집에서 자신의 골프채로 대가리가 깨진 남자
# 2	오케이 마담	10점 준 사람들 알바가 아니라 '나만 당할 수 없다' 는 심보 아닌가?!이건 아무리 봐도 그냥 코로나로 힘든 상황에 배우들 월급 주려고 막 찍은거 같다.온갖 비싼 재료 다 넣어서 잡탕을 끓여 놨는데 심지어 맛도 없어... 미쳐..
# 10	담보	'뻔한 내용이었다' 라는 말들이 많은데 영화라는 건 반전이나 예측할 수 없는 것에서 오는 즐거움과 감동도 크지만 꼭 반전이 있어야만 좋은 영화이고 즐거운 영화는 아닌 것이기에 개인적으로 나의 눈물을 쏙쏙 뽑아내준 영화에 박수를 보낸다^^ 예측하며 보았어도 그 감정이 느껴지는 연기 덕분에 한 번 더 짠하기도 한 번 더 좋은 사람으로 살고 싶게도 느껴지고 했다^^
# 10	원더	오랜만에 느껴보는 큰 감동 ㅠㅠㅠ 보면서 많이 울었다 내 인생영화ㅠㅠㅠ
# 10	죽지않는 인간들의 밤	요즘은 이런 병맛영화가 좋더라 아무생각없이 볼수있는 재밌게봤다 ㅎ
# 2	다만 악에서 구하소서	관객을 뭘로 보고 이런 잣같은 스토릴 들이대? ㅋ
# 1	에놀라 홈즈	핵노잼 ㅋㅋ 근데 존나웃긴게 뭐냐면, 외국페미는 자긍심이 높아서 남자가 여자를 지켜주는거보다 여자가 남자를 지켜주는걸 더 좋아한다. 한국페미는 여자가 남자를 지켜주는것보다 남자가 여자를 지켜주는걸 더 좋아하는데 심지어 그 와중에도 남자가 욕은 더 쳐먹는 페미니즘이 한국 페미니즘이다 ㅋㅋ OO끼들아 ㅋㅋㅋㅋ
# 10	사바하	난 종교가 없다. 이정재가 무슬림소년의 이야기를 하며 잘모르겠다고 말했던것처럼 신에대한 절대적인 믿음이 없고 모순을 이해하지 못한다. 그런데도 힘들땐 종교에 기대고 싶어질 때가 있으며 성경구절을 읽고 위로를 받기도한다. 하지만 나에게 성경구절보다 더 큰 위로는 가족이다. 그래서 처음엔 그것의 존재가 막연하게 무섭기만했는데 마지막엔 너무 슬펐다. 엄마의 노랫소리도 슬펐다. 종교에대해 다 알진 못하지만 인물들의 심정이 많이 와닿았던 영화였다
# 7	피막	무서운데 웃기기도 하고 B급 코메디인데  재미있음.가볍게 보기 좋음. 반전도 있고 마지막에 감동 쬐끔~ 솔직히 한국 코메디 보다 훨씬 나음. 주연 남녀의 찐사랑 부럽네..결말과 엔딩크레딧영상이 해피엔딩이라 좋았다.
# 10	바람	짱구가 마지막에 오열하면서 말하고 싶었던 말 하려는데 아버지가 다 안다 하시면서 웃으시는 거 진짜 늦기전에 아버지에게 떳떳하고 정말 정말 잘 사는 모습 하루빨리 보여드려야겠다 생각이 들었습니다.
# -----------------------------------------------------
# 1	죽지않는 인간들의 밤	웃기지도 무섭지도 재밌지도 않는데..  평점이 이렇게 높다고?!  그리고 결국 양동근의 정체는 뭐였냐?
# 1	국제수사	정말 대단하다.. 이것보다 대단한 영화는 세상에 존재하지 않는다...초반에 '국제수사' 하고 옆에서 제목 날아올때부터 불안함이 엄습했다...그러자마자 똥망인 카메라워크가 화면에 스윽 날아오더니 미묘한 불쾌함까지 일었다.그리고 국제수사랬는데 국제수사라 할만한것도 없고 그냥 감독이 경찰에 대해 똥망인 인식을 갖고있다는 것만 알았다;
# 10	담보	작가님ㅠ상황설정이 너무 잔인했어요 너무 안타까워서 영화가 끝나고도 가슴이 먹먹하네요,,ㅠ결국엔 해피엔딩이지만,,,
# 9	오만과 편견	사랑이 시작되는 순간, 남녀가 서로에게 가지는 오해와 편견을 그리고 있는 드라마, 멜로, 로맨스영화다. 제인 오스틴의 동명소설을 원작으로 한 영화다. 2014년 티비 더빙판을 보고 이번이 두번째 감상이다. 1940년작 오만과 편견, 흑백영화도 본적이 있는데 하도 오래 되어서 기억이 가물가물하다. 남자의 자존심과 여자의 편견을 뮤지컬 드라마형식으로 만든 영화였던 것으로 기억이 난다. 원작의 시대적 배경은 영국 하노버왕가의 첫국왕 조지1세부터 4세까지 1714년~1830년까지의 조지시대를 배경으로 하지만 소설에서는 1790년대를 주배경으로 이야기가 전개된다. 이시대는 분명히 계층간, 계급이 존재했고 결혼문화도 신분과 지위와 부를 따지던 시대다. 남성중심의 사회에서 여자는 좋은 집안에 시집가는 것이 인생의 최고 목표인 시대였다. 다소곳하고 정숙한 여성상이 미덕인 시대에 다섯 자매중에 유일하게 자기 주장이 강한 캐릭터가 엘리자베스다. 이런 여자앞에 나타난 다아시는 자기 중심적인 캐릭터로 겉으로 보기에는 오만하고 냉소적으로 보인다. 이것이 관점의 편견이라고 해야 할까? 이영화의 변곡점은 다섯자매의 삶이 바뀌는 시점인 부유한 귀족 빙글리와 다아시가 마을에 도착하면서 부터다. 처음 대하는 남녀는 가문의 차이에서 오는 선입관으로 서로를 대하고 바라보게 되는데 바로 영화의 제목처럼 오만과 편견의 시각으로 서로를 바라보게 되면서 오해가 쌓이게 된다. 신분과 계급이 존재하고 결혼문화가 가문을 저울질하는 시대에 남녀의 사랑은 진실이 분명 내재되어 있음에도 시대가 안고 있는 편견은 어쩔 수 없을 것 같다. 쌓여만 가는 오해와 편견을 잔잔한 사랑으로 풀어가는 러브스토리에 깊이 빠져들게 된다. 역대 최고의 러브스토리영화라고 해도 손색이 없을만큼 시대를 초월한 멜로,로맨스는 솜사탕처럼 달콤하다. 이영화는 사실을 바탕으로 까는 시대극이라기 보다는 시대의 특성을 시각적으로 묘사하는 픽션형식의 코스튬드라마로 봐야한다. 그시대의 신분과 계급에 따르는 의상, 소품, 풍속, 풍습등을 세세하게 묘사
# 10	남자가 사랑할 때	17살 여고딩이에오 황정민배우좋아해서 황정민배우가나온 영화들을 찾아보고있던중 남자가 여자를사랑할때 이 영화보고 황정민배우님이 더 좋아졌어요 ㅠㅠ 연기하시는것도 너무 감동적이고 감독님 이 영화를 제작해주셔서 너무 감사합니다 2013년이면 제가 초등학교3학년때인데 고등학생이되고나서보니 너무나도 감동적인 영화이네요 보는내내 그냥 슬퍼서 너무 눈물이 많이나왔네요 이 영화를 보시지않으셨다면 꼭 보시길바랄게요 세상 감동 다 모아둔영화네요
# 10	제인의 썸머
# 8	죽지않는 인간들의 밤	이건 매니아성이 강한 코메디임 ㅎㅎ 난 재밋엇음
# 9	죽지않는 인간들의 밤	스토리 연출 다 무난함100만은 넘길 작품인데코로나 땜시 아쉽다
# 4	뮬란	실사화를 하고 대다수가 동양 배우임에도 디즈니 특유의 연출은 그대로여서 그게 종나 위화감드네, 애니는 동양인지 서양인지 솔까 별 느낌없는데 실사로 만드니 짱깨들이 죄다 영어쓰고 제스처도 미국식, 이런 짬뽕은 만들지마라
# 10	노트북	왜 볼때마다 눈물이나지 ㅠㅠㅠㅠ 몇번돌려봐도 눈물 ㅠㅠㅠ
# -----------------------------------------------------
# 10	검우강호	한 번 볼때 다르고 두번째 다르고 세번 보면 보인다. 잘 만든 홍콩영화.
# 10	내가 누구인지 말해주오	최고의 다큐멘터리.... 충격적인 내용이지만, 명작임은 분명함
# 8	테일 오브 테일즈	괴물 저만 불쌍하나요. ?.!?.!?
# 10	황해	몇번응봐도 중독성 쩔움
# 2	어느날	손도움직이고 눈도깜박이는데 식물인간이라고 죽여버리기  미친 ㄲㄱㄲ 감독 사이코패스임?
# 10	왕의 남자
# 10	박쥐	언젠간 영화의 교과서가 될 작품
# 2	82년생 김지영	내가 본 OOO기 영화 원탑.평점은 페미들이 다 퍼주는듯?ㅋㅋㅋ
# 6	탈출	왕정감독의 과유불급 욕심에 헛웃음만 유발되는 반면 장학우의 고군분투가 안쓰러운 영화...
# 9	서던 리치: 소멸의 땅	나와 너의 경계가 사라지고 자연과 하나가 되는 것. 나는 전멸하지만 동시에 새롭게 창조된다. 신이 만든 결함은 보완되어 영원한 삶을 살고, 거짓으로 점철된 마음은 희석되어 전에 없던 교감을 만들어낸다. 쉬머는 지구의 암일까 무한한 생명일까. 불현듯 찾아온 이 존재는 '나'에 대한 믿음이 무의미해지는 저 너머의 세상을 제안한다. 두려우면서 동시에 매혹적인 세계를 영상으로 잘 구현했다고 생각한다.
# -----------------------------------------------------
# 10	먼 훗날 우리	아무생각없이 보려다 입막고 꺽꺽대면서 울었네
# 1	뮬란	별점 0점은 왜 없는걸까? 프리홍콩 프리 위구르족 OO 중국 시진핑
# 6	버드 박스	봐야겠다. 보고수정-.-.-.-./
# 4	알리타: 배틀 엔젤	그냥 그래픽만 볼만하지 스토리가 너무별론데 평점은 왜이리 높냐?
# 7	폰조	연기는 잘합니다 말할거 없구요...내용은 호불호가 있을거같은 애매합니다. 돈의 행방을 찾기 위한 경찰과 늙은 카포네의 스릴러 물인줄 알고 보시면 안됩니다. 늙고 중증치매병든 노인이 벽에 똥칠쇼 하며 망상에 헛소리만 주구장창 해대는 사이코드라마? 인간극장? 입니다. 중간에 인간극장 나래이션도 있다고 상상하고 보면 재밌을거 같습니다. '이런..폰씨가 또 자다가 이불에 똥을 싸고 말았다~' 띠리리링~ 띠링~ 띠리리링 링 링~
# 10	B급 며느리	오늘도 비혼을 다짐합니다..
# 2	타짜: 원 아이드 잭	돈 주고 보기 아까운 영화..심심풀이 수준도 안됨
# 9	죽지않는 인간들의 밤	기대 안하고 봤는데 재밌어요~ㅋㅋ
# 10	바닷마을 다이어리	정말 아름답고 따듯해지는 영화
# 7	메종 드 히미코	과제준비영화로 노인 영화 찾다가 오다기리죠 예쁘게 나온대서 본건데 조호물감독이래서 기대하고 봤음 시오리가 어줍잖게 용서하고 징징 짜고 이러면 어쩌나싶어서 계속 조마조마했는데... 시오리 인간적으로 너무 공감능력이 높은거 아니냐 ㅋㅋㅋㅋ 완전 호구잖어 ㅠㅠ 루비할배 결국은 받아들여졌단게 잘 이해가 안 가긴한다 손녀가 너무 좋아해서 그랬을랑가...  가족애를 굉장히 중요시하는 영화인 것 같다 인테리어 예쁘던데 시오리 가져간 가구 팔아서 돈 좀 받았겠지... ?? 끝까지 시오리의 경제사정이 신경쓰였다
# -----------------------------------------------------
# 10	더 버터플라이	평점이 왜이렇게 낮죠 스릴러물로는 손색없고 배우들 연기도 좋았는데
# 10	아웃포스트	나에겐 블랙호크다운 이상의 영화
# 10	아일라
# 7	임금님의 사건수첩	가볍게 즐기기엔 좋은 영화에요. 마블스런 음악은 좀 많이 안어울리지만
# 3	여곡성	와이프가 진지하게 물어본다. 저 영화를 왜 보는거야?
# 5	폰조	현실과 환각의 경계를 구분하지 못하는 치매 환자가 된 악명 높았던 범죄자의 말로. 스토리보단 인물의 내면 묘사 위준데 정신적인 것에 너무 집중한 나머지 내용이 없음. 톰 하디가 열심히 끌고 가지만.. 음
# 2	컨택트 2020	이게 영화인가 싶을정도다.
# 10	부활: 그 증거
# 10	세상을 바꾼 변호인
# 9	기기괴괴 성형수	정말 기괴하고 기발한 애니입니다.. 지루할 틈없이 집중해서 봤습니다~ 구성 연출 풍자 등 잘 만든 애니영화입니다! 다만.. 약간 그림 모션이 어색한 부분은 좀 있고  15세 치고는 잔인한 장면 등 조금은 수위가 있습니다!
# -----------------------------------------------------
# 1	죽지않는 인간들의 밤	이게 듣던 알바인가? 평점 조작이;;
# 10	밥정	이러면 안되는데.. 극장에서 소리내어 울었다..
# 1	죽지않는 인간들의 밤	진짜 시간아깝다 장점이1도없는 영화
# 10	카메라를 멈추면 안 돼!	영화 연출, 연기, 스토리, 영상미 총집합
# 8	스파이	여자악당이 너무이쁨(레이나).. 주인공은 돼지임..ㅋㅋ 개인적으로 포드 대사가 개웃겼음 별하나뺀건 잔인한장면들이 좀있음
# 10	찬실이는 복도 많지	재미나고~ 사랑스럽고~ 위로가 되는 영화!영화 좋~~~~다!
# 10	남과 여	볼때마다먹먹....
# 10	오케이 마담	졸라 재밌고 엄정화 연기 엄청 잘해요 ㅋㅋ
# 8	특종: 량첸살인기	거짓이 진실이, 진실이 거짓이 되는 세상은 요지경
# 10	노트북
# -----------------------------------------------------
# 8	쉘 위 댄스	25년 전 대학생때 개봉할때 안보다가 40대 중반이 되서야 보았는데, 지금 보길 잘한 것 같다.무언가 끝났다고 생각될때, 여전히 인생을 생기있게해줄건 얼마든지 있음을 깨우쳐준다. '바람을 피우자'
# 9	담보	분명 픽션이고 뻔한 신파도 맞는데 결국 날 울렸다 담보라는 단어가 이렇게 아리게 다가오다니... 그나저나 박소이 이 친구 연기하는 눈빛이 아역이 아녀...
# 10	브레이크 더 사일런스: 더 무비
# 1	나를 찾아줘	별반개도 아깝다. D 마이너스.
# 10	어거스트 러쉬	몇 년마다 한번씩은 꼭 보는 영화. 어떻게보면 너무 우연의 우연이 겹치는 내용들이 많은데도 음악이 모두를 이어준다는 장치 덕에 후반부 부터는 눈물이 줄줄 흐름ㅠㅠ
# 10	담보	존잼이요ㅠㅠ 오랜만에 눈물 콧물 뺐내욥
# 10	가버나움	내 생의 최고의 영화!!
# 7	12번째 솔저	살아야 하는 이유보다는 죽지 않아야 할 이유
# 10	소공녀	기대안하고 봤는데 너무 좋았음 다
# 10	인생은 아름다워	어떤 정치적 ,역사적 스토리인지 알고있었기 때문에 지금까지 안보고 있었는데 어릴때 이 영화를 봤다면 내가 다른 시각을 가진 사람이 될 수 있지 않았을가 싶어졌다. 한 영화 안에서 다차적인 감정을 느낄 수 있게끔 하는 질 높은 영화가 얼마나 될까. 그런 의미에서 나는 내 나이 이전에 나온 영화들을 사랑할 수 밖에 없어진다. 우리가 이 영화에서 아버지의 부성애에 대해 감동을 받을 수 있던건 배우의 연기력 또한 한 몫 크게 했기때문이다. 그 실제 모티브 된 인물과 배우의 연기력이 합쳐져 역사적 아픔보다 감동을 먼저 느낄 수 있다는거. 정말 쉬운 일 아니니까
# -----------------------------------------------------
# 9	고령화 가족	끈끈한 가족 식구들의 코미디 가족극
# 9	웨이 백	긴 여정을 그리는 거라 다소 지루함이 있지만, 그들의 여정을 필름으로 담아내어 마치 다큐를 찍은 듯한 리얼감이 돋보이는 영화였다.
# 10	봄날은 간다	보면서 이렇게 다양한 감정을 느낄 수 있다니
# 10	너의 이름은.	너무너무 감동 그 자체..
# 9	긴급 명령	한 솔로가 다스베이더 밑에서 일하는 진귀한 장면을 볼수있는 영화임
# 10	변산	아 씨... 요즘시대에ㅜㅜ 80년대 티비문학관 같은 느낌의 작품이...  왜 이렇게 담담하고 슬프냐!!!  ㅜㅜ
# 10	선생 김봉두	중반부터 내내 울었다 헤으으으으응ㅠㅠㅠ
# 10	헌터 킬러	이걸 깜빡하고 극장에서 못본게 아쉽다 개지밌네
# 10	담보	배우분들이 너무 연기를 잘하세요 볼때마다 울컥
# 1	브이아이피	마지막에 이종석이 살이 있는 채로 목을 잘랐으면 2점 줬을텐데
# -----------------------------------------------------
# 10	어웨이 프롬 허	OST가 좋아서 보았는데 정말 짠하네요.기억이란 무엇인지,사랑도  기억이 사라지면 없어지는지 생각하게하네요.정신있을때 더 사랑하고  잘해주어야겠네요.
# 10	죽지않는 인간들의 밤	이거 재미만 있구만 멀 알바 알바 거리지?오히려 별점 테러 하는 알바가 있는듯
# 5	해무	이희준 캐릭터 진짜 어이없네ㅋㅋ
# 10	좋지 아니한가	병맛 코미디여서 가볍게 볼 수 있었고 끝에 메시지가 분명해서 더욱 좋았음. 황보라 배우 나레이션 좋았고 밥통씬은 진짜 깜놀했음ㅋㅋㅋ 한 번쯤은 봐도 좋을 영화.
# 9	악마는 사라지지 않는다	죽임... 금전을 위해. 권세를 위해. 사랑하는이를 위해. 이상을 위해. 약간 노인을위한 나라는 없다 와 비슷한 느낌을 받음... 내포된 메시지가 강할듯
# 10	미드나잇 인 파리	사람들은 항상 과거를 그리워한다내가 앞으로 그리워 할 과거는 지금이다.당연하지만 지금의 가치를 다시 일깨워주는 영화 였습니다~~
# 2	헬보이	뭐랄까 진짜 재미없음.... 억지로 징그럽고 그로테스크하게 만든 것 같아요
# 1	강철비2: 정상회담	진짜 너무 심했음 영화 막눈인데도 최악 영화
# 9	우리들의 일기	괜찮던데. 옛 감성에 빠져서 본듯. 오랜시절알고지낸 친구들에 대해 생각도 나고. 전체적으로 괜찮았다.
# 5	폰조	조악하고 유치한 연출 거기에 톰하디 과잉몰입졸작
# -----------------------------------------------------
# 10	다만 악에서 구하소서	기대 안하고 봐서 그랬나? 기대 이상의 영화..액션이 액션이 액션이 우와~~~~하고 집중..
# 10	그는 당신에게 반하지 않았다
# 10	블랙핑크: 세상을 밝혀라	국내 최정상 걸그룹인 블랙핑크의 데뷔전 모습에서 현재의 모습이 되기까지의 많은 과정과 노력들이 고스란히 보이는것 같아 멤버들이 하나 둘씩 울때, 너무 감동적이었어요. 내 최애 가수 블핑 언제나 응원합니다! 데뷔해줘서 고마워요♥
# 4	시체가 돌아왔다	와내가 김옥빈이거나 김범수엿으면 진짜 국정원 여자 개팻다 진심 여자 땨리면안된다 주의인데  ㅡㅡ 암덩이네 ㅡㅡ
# 10	담보	스토리, 배우들 연기 다 너무 좋았어요특히 아역배우가 연기를 너무 잘해서 계속 울컥했어요ㅠㅠㅠ
# 10	미씽: 사라진 여자	진짜 꼭 보세요... 공효진 미쳤습니다..
# 10	오케이 마담	재밌어염!!!  가족끼리 보기 좋아요!!!계속 웃으면서 봤어요ㅎㅎ
# 10	안녕까지 30분	진짜 재밌습니다 보러가세요 다들 ㅠㅠㅠ 오슽도 음원 사이트에 있으니까 영화보고 오슽까지 들어주세요 연출 연기 노래 다 최고
# 8	박화영	문제는 실제로 이런 ㅂㅅ같은 일진놀이하는 학생들이 있다는거다.   제발 자격, 능력 안되면 애낳지 맙시다. 그런 애들이 저렇게 되는겁니다.
# 10	폴라	아니 ㅋㅋ 떡신은 왜 넣냐고 ㅋㅋㅋ 미쳐따
# -----------------------------------------------------
# 6	덩케르크	연기는 대단하고 스토리는 단순하다,그러나이런 스토리도  100분정도의 영화를 만들어내는 것도 대단.
# 9	언힌지드	러셀크로우 연기 진짜 미친ㄴ 같음. 요즘 분노범죄가 많아졌는데 있을법한 이야기지만 여캐 답답함.
# 4	데스노트: 더 뉴 월드	막 너무 재미없는건 아닌데 1,2편과 비교를 하니 스토리가 탄탄치 않음...유전자를 남겼다는 설정이...애바여 ㅡㅜ 차라리 3탄에서 나온 수학천재 니어가 커서 나오면 말이라도 되지... 그건 그렇고 최악은 류자키...ㅡㅜ 얼굴보고 판단하면 안되고 연기만 잘하면 되지 외모가 뭐가중요해 라고 생각했지만 내 생각을 씹어먹어주심.... 매우중요했다 ㅠㅠ몰입감떨어져
# 10	메리 크리스마스	크리스마스의 기적..
# 10	귀향
# 6	더 배드 배치	사막에 있으나 컴포트에 있으나 '무언가'를 잃고 영혼없는 사람들. 무엇이 옳고 그른가가 불명확한 아노미세계에서 '무언가'를 스스로 찾아떠나는 여성의 이야기. 구성은 아쉽다.
# 6	언힌지드	러셀크로우 연기는 잘함 그런데 살이많이찜  확찐자가 된거같음동질감이  느껴진다 ㅠ,ㅠ
# 10	그대, 고맙소 : 김호중 생애 첫 팬미팅 무비	김호중 그대고맙소 처음에 남편과 함께 관람을 했는데 김호중 가수님의 진정성 가득한 표정과 따뜻한 마음, 그라고 천장을 뚫을듯한 폭풍 가창력에 벅찬 감동을 받고 돌아왔습니다 그 여운이 가시질않아서 지역 마지막 상영날 다시 딸과 함께 관람하게되어서 얼마나 행복했는지요 특별히 관심이 없던 딸마저도 감동에 빠뜨려 눈물짓게 했으니~~늘 진심을 다해 노래하는 김호중 트바로티 리스너를 뜨거운 감동으로 전율케하는 최고의 뮤지션 언제까지나 사랑하고 응원합니다
# 1	죽지않는 인간들의 밤	평점에 속아. 그저 이정현이 좋아 보았는데...참다참다 평쓴다..이건뭐 출연자들 전부를. 그들의 경력을 삼류로 만들어버린 영화다...
# 10	에놀라 홈즈	셜록홈즈의 여동생이라는 설정이 흥미롭다그당시 여성에 대한 사회적 지위가 제한된 시대에 탈코르셋을 외치며 스스로 자신의 꿈을 펼치고 개척해가는 에놀라라는 인물은 멋지다 그리고 듀크스베리의 레오나르도 디카프리오 뺨치는 미모와 에놀라의 나탈리포트만의 재림이라고 할수있는 아름다움에 볼만했다 또 유도리아의 "너희 미래에 지금같은 세상을 물려주기 싫어서 그래서 투쟁을 해야했다"던 여성의 선거 투표권을 위해서 깊은 뜻이 있었던 실종은 이해할만 했다
# -----------------------------------------------------
# 10	잉투기	류혜영보고 설렣다ㅎㅎ
# 10	무서운 집	크.. 전국 관객수 1,103명... 그중에 한 명이 저였습니다. 당시 하도 화제가 된 영화라 궁금해서 친구 꼬셔서 같이 보러갔는데 극장에 저희 둘밖에 없었습니다. 영화 보는 내내 친구한테 미안해 죽을뻔.. 관객이 둘밖에 없어서 도중에 나오지도 못하고 끝까지 봤네요. 그다음부터 친구에겐 항상 사죄하는 마음으로 살고 있습니다.
# 8	죽지않는 인간들의 밤	양동근 이미도 땜에 그나마 재밌었음. 초등학교 어디 나오셨어요? 할때마다 웃겨죽음ㅋㅋㅋㅋ
# 10	부활: 그 증거	확실한 믿음이 생기는 영화 최고입니다
# 8	갤버스턴	영화는 이래야지...어두으면서도 잔잔한 액션 인상 깊었음...그렇다고 스토리가 허전 하지 않다....
# 10	동감	선선한 날씨에 보기 좋은 명작..진부한 클리셰여도 마음을 울리는 느낌이 있는 영화
# 8	론 서바이버	그럭저락 볼만했음.. 다만 탈레반과 미국과 대립하는 근본적인 이유를 알고싶네
# 6	역린	너무 극적인 연출에 힘을 준 느낌. 재밌게는 봤습니다.
# 1	죽지않는 인간들의 밤	대박이다..;;뭘 먹고 만든거지?;;
# 2	죽지않는 인간들의 밤
# -----------------------------------------------------
# 10	교실 안의 야크	영상으로 나타나는 부탄의 절경과 때묻지 않은 아이들로도 충분히 힐링되는 영화. 그 안에서 나타나는 몇몇의 클리셰가 결말 부분에서 임팩트있게 느껴져 좋았던 영화.
# 8	덩크 슛	스나입스가 싸이클 쪽모자을 계속 쓰고나오는데콜나고 타임 등등 ㅎㅎㅎ이유 아시는분 있나요싸이클은 흑인의 스포츠가 아니었고 지금도 아니긴 흔데
# 8	온워드: 단 하루의 기적	실패없는 디즈니&픽사 뭔가 소소한부분부터 현실적임..주제가 현재 같이사는 사람부터 충실하자 같은데 그래도...가족들 다들 한마디씩은 하게해주지..
# 6	아내가 결혼했다	넷플릭스에 있길래 봤는데 ㅋㅋ  결국 재경이는 세컨이었던것 같다 한국법상 둘다 공평할순 없지 ㅋㅋ서류의힘
# 10	비밀은 없다	손예진 배우가 여기서 포텐이 터진 모양입니다. 고 김주혁 배우의 연기도 단연 돋보입니다. 이경미 감독의 진짜 엄청난 연출력까지 영화가 삼합이 잘 맞네요. 제목이 단순하면서 적절하게 지어졌네요. 박찬욱 감독의 냄새가 난다했더니 정말 각본에 참여하셨었네요ㅋㅋ 이경미 감독의 독창적이고 새로운 시선의 연출을 깊이 응원합니다 앞으로 더 좋은 작품 많이 만들어주세요. 손예진 배우님께도 좋은 작품 많이 몰려서 한국영화 더 흥하길!
# 9	그린랜드	가족영화입니다. 온가족이 같이 볼 수 있는 영화이기도 하고, 스토리 자체도 가족애를 깊이 다루고 있습니다. 그 다음이 재난영화입니다. 저는 이것 위주의 영화인 줄 알고 보기 시작했는데,  보고나니 오히려 재난은 두번째라는 느낌이 들었어요. 저는 가족영화도 좋아하기 때문에 일석이조의 느낌이었지요. 스토리는 예고편에서 본대로 심플하지만, 그 과정을 즐기며 보아야 하는 영화인듯 합니다. 액션 강한 영화 원하는 분보다는 가족영화 원하는 분께 좋은 영화입니다!
# 7	철벽선생	뭐 어느정도 현실적이라면 현실적 결말같음사마룬 단발이낫다 트레이드마크다 하는데 가발이 너무 답답한 통가발이라 그렇지 개인적으론 긴머리가 더좋음
# 1	뮬란	원작 다 망쳐놓음 보지 마셈
# 1	죽지않는 인간들의 밤	요즘 한국영화들 왜 이러냐 망해가나... 정말 심하다 심해 돈 아깝다
# 7	그린 러시	실화 바탕이라는게 신기하네요.근데 좀 잔인하고 슬퍼요ㅠ연기나 짜임새 완성도는 상당한데 내용이 암울해서....;;
# -----------------------------------------------------
# 10	퍼펙트맨	재밌기만하구만 평론가평점이 왜저런지..
# 6	퍼펙트맨	뒷심 부족~ 그나마 조진웅...
# 1	인 타임	황금소재로 똥죽을 써놓은 감독은 어떤인간인가 찾아보게됨.. 아깝다 진짜
# 1	나쁜 남자	생각이 쓰레기인걸 인정하는 영화인듯
# 10	안녕까지 30분	스토리 자체는 다소 평온하고 평범하여 매력적으로 다가오지 않을 수 있지만 OST 음악이 함께하기 때문에 모든 장면 하나하나가 매력적으로 다가온다.
# 9	#살아있다	심장 쫄깃쫄깃 맘졸이며 집중해서 봤어요~ㅋㅋ유아인씨 연기가 역시 돋보임. 자기전에 재밌는 영화보고 잡니다
# 10	에이리언 2	"we're in the pipe, five by five" - 불쌍한 엄마 에일리언 ㅠ 조그마한 혹성 LV-426에서 새끼들과 함께 알콩달콩 살았는데 무식한 인간 해병대와 함께 온 리플리란 인간 여자에게 몰살당하다니
# 10	그린랜드	개인적으로 마음에 들었던 영화
# 10	퍼펙트맨	난 그냥 코믹영화인줄 알았는데 완전 휴먼 스토리네... ㅠㅠ
# 10	방황하는 칼날	사적인 복수는 안된다? 사적인 복수를 하지 않을 만큼 법이 큰벌을 주면 된다 물론 난 아무리 큰 벌을 줘도 사적으로 복수 할거다
# -----------------------------------------------------
# 2	언힌지드	영화보다가 나온적은 처음임. 돈주고 왜 이런 스트레스를 받으며 봐야하나
# 8	구슬 동자	백수노래가 생각나는 만화
# 10	폰조	이건 톰하디만이 소화 할 수 있었던 영화인듯..
# 9	동주	윤동주의 삶을 영화를 통해 보고 또 간간히 윤동주가 썼던 그 시기에 맞는 시를 강하늘이 낭송하면서 시의 대한 이해, 울림이 훨씬 커졌다. 그 시를 썼을 때의 마음, 배경, 고뇌가 잘 표현되어 있었다. 윤동주의 시는 최고의 음악이었다.
# 7	강철의 연금술사 - 시리즈	원곡 오프닝곡보다 중국어 버전곡이 더 기억에 남은...
# 10	부활: 그 증거	예수님의 부활에 대한 믿음의 단서를 찾을 수 있었다.
# 10	설리: 허드슨강의 기적	각자의 자리에서 최선을 다했더니 그 결과는 기적이었다. 1549편 여객기에서 가장 마지막에 탈출한건 마지막까지 승객을 살피다가 나온 승무원과 부기장 그리고 기장이었다. 이 당연한 사실이 너무나도 슬프게 다가오는건 어째서일까.
# 1	은밀한 유혹	제목과 너무 안 어울리는 스토리 전개 일단 임수정 유연석 이경영의 연기는 훌륭 단 스토리가 전혀 못 따라감 그냥 삼류 유치 짬뽕 신파 고전 클라쎄 수준 제가 이 영화 보다 느낀건데 드라마 샐러리맨 초한지, 영화 블라인드, 어린 의뢰인의 한 장면이 떠올랐음 너무 작위적 설정들이 남발 결말 또한 너무 아쉽다 요즘 관객들 수준이 얼마나 높은데 이런 영화를 보겠나? 주인공 빼곤 나머지 조연들 연기도 다 어색 배경까지도 그냥 유연석만 멋있었음 그냥 보시려거든 배우들의 열연에만 집중해서 보시길
# 10	변산
# 8	죽지않는 인간들의 밤	와ㅋㅋ 양동근형님 덕분에논스톱 이후로 이렇게 현웃 터진건 오랜만입니다ㅋㅋㅋㅋ 개웃기네ㅋㅋㅋ
# -----------------------------------------------------
# 10	담보	어흑..끕...엉ㅇ엉 너무 슬퍼요 마음이 따뜻해져요
# 1	죽지않는 인간들의 밤	 시간아깝다고 지인들에게 말해줌  누적관객 10만명에 VOD 나올정도면 말다햇지
# 8	죽지않는 인간들의 밤	은근 잼있다. ㅋㅋ  이정도면 중상박인데
# 6	폰조	악랄한 범죄자의 비루한 말년
# 2	죽지않는 인간들의 밤	장난해???? 미친 8.83??? 사기
# 10	베테랑
# 10	미녀와 야수	????????????????
# 10	폰조	환영과 과거를 넘나 드는 치매환자를 지켜 보는 흥미로운 영화
# 10	악마는 사라지지 않는다	불쾌하면서 유쾌하다 적어도 아빈은 악마가 아니다
# 9	남매의 여름밤	실제 가족이 살고 있는 집을 섭외해서 감독이 상상할 수 있는 그 이상의 사실성과 축적된 시대를 온전히 담아내고 있는 집이 또 하나의 주인공
# -----------------------------------------------------
# 10	디태치먼트
# 1	폰조	진짜 제발 보지마세요 내용이 없음 보고나면 ????만 가득
# 1	헝거게임 : 더 파이널	만약 이영화가 재미있다고 강추하는 사람들은 다 12세미만이거나 정신이이상하거나 알바이거나 셋중하나일듯.. 1편부터 4편까지 쭉 이어서 다본사람으로써 15세이상이라면 절때봐선 안될  최악의 영화였다. 아무리 판타지영화라지만 하지말라는거 다하는 주인공 이남자 저남자 양다리의 끝을 달리면서 합리화만하는 여자임에 틀림없음. 지도 살려고 게임에서 사람들 죽여놓고 전쟁은 안된데 지동생죽으니까 바로 대통령죽임ㅋ 정말어이가없음  영화자체가 초딩영화라서 그런지 너무 유치하고 생각이없음하지만 ost하나만은 좋았음
# 10	기기괴괴 성형수	정말 재밌어요 제가 본 애니 영화 중 역대급이네요 영상미도 좋고 네이버에 뜰 때까지 기다린 보람 있네요!!
# 10	이보다 더 좋을 순 없다	너무 감동적인 영화누구나 완벽한 모습은 아니지만 저마다의 사랑과 행복을 품고 산다영화 보면서 여러번 눈물을 훔쳤다
# 8	강철비2: 정상회담	재미는 확실히 있긴하다.
# 2	그린 마일	지금와서 다시보니 똥작이었네요 흑인은 절대선 더하기 무슨 초능력자. 여자는 무조건 약자에 피해자 남자는 가해자 아주 토나오는 페미pc영화였음ㅋㅋㅋ
# 9	더 페이버릿: 여왕의 여자	참으로 감각적이고 구별 가능한 요르고스 란티모스식 영화.남성 캐릭터 소비와 전개, 비유와 연출까지 뛰어나고 특별하다
# 1	죽지않는 인간들의 밤	이거 보고 암이 생겼어요
# 2	싸움의 기술 2	액션은 그나마 볼만한데 서사가 너무 부실함 영화의 생명은 서사인디
# -----------------------------------------------------

# %%
#파일명 : exam5_3.py
import urllib.request
from bs4 import BeautifulSoup
data = urllib.request.urlopen('https://comic.naver.com/genre/bestChallenge.nhn')
bs = BeautifulSoup(data, 'html.parser')
title = []
summary = []
rating = []
titleList = bs.select('.challengeTitle > a')
for titleDom in titleList:
	title.append(titleDom.string.strip())
summaryList = bs.select('.summary')
for summaryDom in summaryList:
	summary.append(summaryDom.text.strip())
ratingList = bs.select('.rating_type > strong')
for ratingDom in ratingList:
	rating.append(ratingDom.get_text(strip=True))
print(title)
print(summary)
print(rating)
# Out:
# ['우리는한팀', '30일후', '아빠는 N살', '공작일보 工作日报', '산군대잔치', '88한 인생', '하임의 서재', '신과 인간', '카나와 초나의 독일', '서폿저택에 어서오세요', '미줌툰', '모두의 미아씨', '좋아하는거 참으면 병나요!', '아오링도쿄', '낮잠 자는 사람들', '겨까게 사랑한다', '고등학교 수감기록', '마왕이 되는 방법', '자체공강', '솔직히 말해서', '너의 여집합', '신혼좀비', '잘먹는 가', '가족같은회사']
# ['어느 가족 이야기', '미래를 알게된 남자', '아빠 4컷 그림일기', '보부장의 상해 살이', '강아지 산군의 일상', '팔팔한 커플 이야기', '비블리오 판타지', '신과 인간의 이야기', '독일 생존기', '서폿만 사는 저택', '미국 줌마의 일상', '미아씨의 매일매일', '좋아하는건 못참아', '도쿄 시트콤', '지하창작인밀착일상툰', '반려묘와자취라이프', '고삼은 존버한다', '자유연재', '대학물인척하는 만화', '로맨스판타지개그만화', '네가 없는 세상', '러브 코믹 호러', '먹는게 낙인 가족들', '완결']
# ['8.57', '9.57', '9.90', '9.18', '9.85', '9.16', '9.89', '9.88', '9.87', '9.85', '9.84', '9.19', '9.68', '9.82', '9.90', '9.32', '9.77', '9.82', '9.87', '9.73', '9.82', '9.89', '9.70', '9.86']

# %%
import urllib.request
from bs4 import BeautifulSoup
title = []
summary = []
rating = []
for n in range(1,31):
	data = urllib.request.urlopen('https://comic.naver.com/genre/bestChallenge.nhn?&page='+str(n))
	bs = BeautifulSoup(data, 'html.parser')
	titleList = bs.select('.challengeTitle > a')	
	for titleDom in titleList:
		title.append(titleDom.string.strip())

	summaryList = bs.select('.summary')	
	for summaryDom in summaryList:
		summary.append(summaryDom.text.strip())

	ratingList = bs.select('.rating_type > strong')	
	for ratingDom in ratingList:
		rating.append(ratingDom.get_text(strip=True))
print(title)
print(summary)
print(rating)
# Out:
# ['우리는한팀', '30일후', '아빠는 N살', '공작일보 工作日报', '산군대잔치', '88한 인생', '하임의 서재', '신과 인간', '카나와 초나의 독일', '서폿저택에 어서오세요', '미줌툰', '모두의 미아씨', '좋아하는거 참으면 병나요!', '아오링도쿄', '낮잠 자는 사람들', '겨까게 사랑한다', '고등학교 수감기록', '마왕이 되는 방법', '자체공강', '솔직히 말해서', '너의 여집합', '신혼좀비', '잘먹는 가', '가족같은회사', '너어는지인짜', '결혼하고 싶지 않았는데 못하게 되었다.', '너구리네 육아일기', '테이커', '광해와 이순신', '우리는 친한친구', '개판오분전', '그날의 우리', '선선한 이야기', '무엇이든 그려드립니닷!', '애니메이킹', '옆집에 그녀가 산다', '신과의 대화', '달의 문지기', '메멘토모리', '그림자게임', '할로윈이 끝나기 전에', '모지리전', '나는 마요 집사로소이다', '웹툰왕', '클리셰', '장르 섞인 만화', '조선귀변사', '소환진이 좀 이상해 보이는 건 기분 탓이겠지', '이세계 국밥 마스터', '낯가리는 관종', '모야툰', '집에가고싶다', '바이러스 X', '실험학교', "86'd", '꿀꾸리? 꿈꾸리!', '슈체나리움 (Szenarium)', '일상견문록', '원더키퍼', '오늘도 그래고래', '아파지는 중입니다', '저승파견고용직', '허니허니2 - 느리지만 괜찮아', '구나의 그랬구나', '로그 아일', '저는 용사님이 아닌데요!', '30일의 시간여행', '너의 뒤에서', '문어숙희숙회', '재테크는 스크루지', '주저드', '집순이에 대하여', '매지컬팡', '포도나무 소녀', '너머의 항하사', '전지적덕후시점', '나의 애니메이터 이야기', '다람쥐 란란', '타챠노트', '이래서 애들은', '백온더트랙', '뿅가이', '채똘일기', '괜찮아, 고3이야', '52번지 몬스터', '궁미일기', '일주일 지구체험', '쓰레기 성의 소녀', '주말엔 보랏빛 향기', '월국(月國)의 프락세이스', '39℃', '벌레 이야기', '여긴 불빛이 안 드는 곳이야', '니사정 내사정', '스프린터', '굥이의 하루', '158동 진상부부', '국밥왕', '사쟈툰', '아이엠', '이리(iri)', '남의 사랑 이야기', '원인탐구생활', '팔재叭災', '쿤도브라더스', '이래봬도2학년', '왕과 나', '한국 프로야구사', '더 익스트림', '천사는 야옹', '당할연', '나를 죽이는 방법', '소극적 인간', '덩키파티', 'THE 극한가장', '제 소원을 들어주세요!', '힝구의 견생일기', '횡설수설 다이어리', '언니가 돌아왔다', '누루누루 음식만화', '우당탕 입큰이', '위치파이와 미드나잇주스', '수능0등급', '어느 남고생의 하루', '천상대전', '모노톤 책꽂이', '엔드시즌', '자작 보드게임 동아리', '판타지 TV', '기억 속 너에게', '오마이갓', '무대에 서지 않지만 배우입니다', '몬스터 커맨더F', '야귀록', '지몽', '식봉툰', '도담도담', '귀염뽀짝 애기뚱냥 뽀냥이', '고란툰', '게임에 접속했습니다!', '의대생 하루', '얼어붙은 아로와향기', '주짓수와 고양이', '결혼 후, 보통의 삶', '우당탕탕 재끼 일상', '만화 임진왜란', '소피아가 머리카락을 쓸어넘길 때', '여기서 한잔할래?', '토마', '느린한끼', '어둠의 창', '닐리리맘봉', '김작가의 오춘기 그림일기', '지나온 길', '모두의 단편선', '벨시토', '대학원 탈출일지', '그날, 우리들의 여름.', '플라시버', '팬시x팬시', '치즈범벅', '봄날의 산보', '지극히 평범한 생활', 'CMYK', '이상한사무실', 'STONE AGE', '여행 다운', '윤덩까툰', '미친 꽃은 답도 없다', '맹랑맘마 MEMORY', '백일몽화원', '대공녀는 거기에 없었다', '검은유성우', '애포칼립스', '곤충전', '비공략 캐릭터를 공략하는 방법', 'Jun과 나', '덴큐', '화분', '개구리툰', '풋내기들', '어른이', '돌레인더시티', 'F I X', '이클립스', '도원향', '싸카소녀', '중등 생활 보고서', '외국 in 한국', '봉산코믹스', '양송부부의 맛있는 한잔', '열여섯과 스물 그 사이', '하나리즈', '버그 트레인', '하이스쿨 콤플렉스(마이동풍)', '나의 별에게', '괴물의 바다', '엑스마키나', '무선혜드셋 정보툰!!', '눈치없는 내 친구!', '아재소녀', '홈 스윗 홈', "LADS'PARTY", '정신과심리만화 by 팔호광장', '브레인 스톰', '마이툰', '주작작 주주작', '왕과 그림자와 여자', '국제결혼개그만화', '네펜데스', '모솔탈출 일대기', '개인적인택시', '그래도 하루는', '월혼', '도와줘요 사신님!', '숲의 향연', '하아의 하루', '모던 던전 판타지아', '슬픔을 먹는 남자', '마법약사', '노바', '졸렬☆다이나믹', '능력안경', '내과 박원장', '사업왕 심길후', '프러미스 : 증오의 찬가', '만월에 핀 연꽃', '틈', '종이를 주웠다', '사랑의 헌옷수거함', '네, 아직 아파요', '은해갑을깝치', '일찍 자고 일찍 일어나기', '공허의 숲', '죽음과 동화', '제목이 7080 만화', '가상&RPG', '소소일기', '인생은 너울너울', '나의 수상한 행성', '용사님이시다', '이데아 프로젝트', '소망툰', '곰의 딸', '일상중의 일상툰', '맛있는 남자', '무지개다리 파수꾼', '분노의 난임일기', '골신 파람', '스푸키 멜로디', '내 매력에 퐁당', '트랜스휴먼', '나타나주세요!', '안녕, 앨리스', '신의 마녀', '빵뽀시래기', '사도 신여랑傳', '아수라게이트', '봄이와', '스크럼블 에그!', '오늘도 분홍했분홍', '곰팡남녀', '울트라 캐피탈', '아틀레냐', '단편들', '어디사세요', '검은선', '이런우정', '여우자매', '쉼터에 살았다', '크림슨 크로스', '우리집 강아지는 복슬강아지', '이매망향 魑魅望香', '어쩌다 햄스터', '올어바웃 You', '청부업자와 소년의 이야기', '강가네', '우로보로스', '런어웨이', '출근하개', '스물 다섯, 어디로 가야 하죠?', '미대생 댕댕', '엑스트라 Z씨', '봉츄툰', '저승사자 이야기', '우주n은하', '목소리의 그늘', '코스믹 코믹스', 'DJ 카일하우스', '지나치게 달콤한', '너와 가까워지는 거리', '블랙펄', '혼자앤피스', '공주님은 알바중', '문러버', '이중에 여자는 하나', '함께 할 때까지', '에밀리 이야기', 'ZET', '아좀비', '잠자던 숲속의 공주', '산타공무원', '백일고 상상클럽', '해동요', '이과지옥', '마족사제', '여자 공수혁', '광고감독의 발암일기', '악인', '정령왕즈', '게으른 고양이의 soso한 카페이야기', '애쉬그레이', '전기수 VLog', '결벽증 소녀', '가면', '기프트!', '왕립 루브리카 종합학원', '가위바위보', '마음의 온도', '성장통 소나타', '미스터 신데렐라', 'ㅎㅋ고모리', '핫차!핫차! 차나무生', '여름의 퀄리아', '사랑하는 계절', '3인3색 세쌍둥이', '냥모나이트', 'LIVE 썸&쌈', '설레이는 나날', '나라 구한 전생', '봉다리', '우주수렴법칙', '1인칭 외국인 시점', '500원 토끼', '고냥고냥', '포-갓', '피치인러브', '이오타', '이왕이면 아이돌', '마롱의 마카롱', '심연', '러브 유어 시스터', '우주의 수호천사', '냥만연애툰', 'Hello Death! [헬로데스]', '손근손근', '서울크로니클 / ALPHASEOUL', '번혼', '리얼 김영감 게임', '은룡여린설', '저주와 별가루', '빨간 물고기', '바다다람지 육지상어', '하나뿐인 안드로이드', '진짜 다 이루어줘', '이별의 플라시보', '밝은미래', '도돌이표', '너와 나의 몰디브', '동거의 법칙', '운명...인가요?', '드리머즈', '학교다녀오겠습니다', '20&21세기남매', '어느새 대학생 ...
# ['어느 가족 이야기', '미래를 알게된 남자', '아빠 4컷 그림일기', '보부장의 상해 살이', '강아지 산군의 일상', '팔팔한 커플 이야기', '비블리오 판타지', '신과 인간의 이야기', '독일 생존기', '서폿만 사는 저택', '미국 줌마의 일상', '미아씨의 매일매일', '좋아하는건 못참아', '도쿄 시트콤', '지하창작인밀착일상툰', '반려묘와자취라이프', '고삼은 존버한다', '자유연재', '대학물인척하는 만화', '로맨스판타지개그만화', '네가 없는 세상', '러브 코믹 호러', '먹는게 낙인 가족들', '완결', '아주 조금 요란함', '안하느냐 못했느냐', '육아일기', '17살의 킬러', '전쟁을 이긴 영웅들', '친한친구 이야기', '좌충우돌 성장통', '우리들의 이야기.', '선선한 하루 되세요', '무엇이든그려드립니닷', '애니메이션 만들기', '옆집의 특별한그녀!', '즐거운 이야기', '달토끼 이야기', '죽음을 기억하라!', '시즌2 시작합니다.', '마지막 인사', '모지리 라이프', '쉽지 않은 집사생활', '웹툰 작가 도전기', '악당들의 입장에서!', '개그랑 로맨스 섞임', '사도세자의 퇴마기', '판타지 일상물', '그 돈이면 국밥먹지', '낯가리는 관종일기', '모야의 일상', '집곰팡이의 일상', '각성자,생존,능력물', '변형자들의 학교', '주방 만화', '중학생 꾸리일기-', '덩굴처럼얽혀오는사건', '다른나라 일상이야기', '너를 지키는', '힐링 미스터리 웹툰', '청춘남녀 성장로맨스', '기묘한 만화', '초보아빠 육아일기', '어린이집 교사냥이', '판타지 생존기', '마녀라고요!', '응답하라!80-90', '사랑따위...', '문어숙회를 위하여!', '초보자용 재테크웹툰', '동물 마법사 이야기', '집순이들의 일상', '명랑만화 매지컬팡', '포도나무', '육도퇴마소년판타지', '나의 덕질 라이프', '나는 애니메이터', '마이웨이 일상', '프리랜서일기', '다양한장르의 거짓말', '서른의 우리에게', '간다 간다 뿅간다', '채똘일기', '너와나의 리얼고3툰', '설렘살벌 로맨스릴러', '평범한 일상 육아', '외계인과의 일주일', '소녀의 성장기.', '성장 로맨스', '소년과 세계,스피릿', '꿈을 이루는 끈기', '킬러와 그녀', '학교 로맨스 코미디', '모든일엔 이유가있다', '단편만화 모음집', '굥이의 하루', '부부의 진짜 일상', '그것이 국밥이니까.', '사쟈를 그립니다.', '파란만장아이돌라이프', '격주 일요일', '조금 늦은 첫사랑', '일상, 고양이', '도사와 겨울아들', '개와 고양이의 동거', '초등학교 이야기!', '세자는 여인이다.', '프로야구 역사만화', 'TheExtreme', '고양이가 사실 천사', '당신도할수있다연애', '지워낼수 없는 후회', '드라마 스릴러', '머저리들의 모험담', '네가족의 일상툰', '중요한걸 잊고있었어', '동네개들의견생라이프', '40대 가장의 일상', '죽은언니가 돌아왔다', '음식 탐닉 공감툰', '드라마같은 일상', '내 인생은 내 인생', '고3 vs 테러범', '말하는강아지가사실은', '천상대전', '누군가의 이야기들.', '초딩들의 야구', '자작 보드게임 만화', '판타지의 인터넷방송', '루와 메르의 이야기', '신을 뽑는 오디션', '배우 지망생 이야기', '몬스터 판타지', '어몽룡의 사랑이야기', '나에게 살해당하다.', '일상적인 이야기', '두더지 모험 힐링', '귀염뽀짝한 애기뚱냥', '고란이의 일상이야기', '게임하는 고딩들', '의대생의 리얼 일상', '청춘들의 쿨 로맨스', '주짓수에 빠진 집사', '묘한 중독 짱매의 매일매일', '부부,일상,공감', '쉽고 웃긴 임진왜란', '학원 일상 추리', '수달의 혼술툰', '의문의 전학생', '요리 만화', '어둠의 끝에서...', '나와맘봉이의이야기', '오춘기를 앓고있어요', '학원 성장 드라마', '모두가함께하는웹툰', '추억과 환상.', '대학원에서 살아남기', '여고 육상 성장기', '믿음대로 될지어다!', '팬시 회사 로맨스!', '치즈고양이형제 일상', '봄날에 산보하듯', '말만 평범한 일상툰', '의식의 흐름 만화', '디자인 회사 이야기', '스릴러 판타지', 'TMI 여행일지', '시즌2 완결', '로판 / 자유연재', '다시 쓰는 일기', '7,17,27일연재', '가상중세시대물', '동양풍 이능력물', '좀베창궐 문명파괴', '판타지', '최애를 공략하라!', '색있는사람들의이야기', '끝나지 않은 이야기', '그런 세상 이야기', '개구리의 일상툰', '청춘하숙 로맨스', '어른이 되어가는 중', '본격 여행가는 만화', '타임리프호러로맨스', '자유연재', '우주경찰서 도원향', '소녀들의 스뽀오츠!', '현실 중딩 보고서', '영국인의한국생활', '비극과희극 단편선', '술이 있는 일상', '툭탁 격정 로맨스', '레즈비언 커플이야기', 'NPC들의 생존기', '청춘로맨스', '감성로맨스', '바다로 가는 이야기', 'SF액션', '잡상식을 재미있게', '격주연재 목요일 밤', '시즌2 !!', '네식구 사는 이야기', 'SF 소년 판타지', '알고싶니 마음', '기억들의 배틀로얄', '두딸키우는 아재일상', '영짐승 배틀물', '되풀이되는 관계', '한-러커플 일상만화', '환경 판타지 스토리', '모쏠 탈출 일대기!', '음악이 흐르는 택시', '희노애락 투병일기', '여우인간의 생존사투', '인간 되기 싫어요', '인격이 있는 숲.', '강아지 일상툰!', '현대풍 던전판타지.', '성장물,감성,판타지', '포션장사하는 이야기', '코지 미스테리 로판', '다이나믹 초딩들', '안경장르 만화', '의사가그린 의사만화', '사업왕 심길후', '.', '구)달무리의 밤', '틈을파고드는 이야기', '종이의 성장과 사랑', '짝사랑은 이제 그만', '정병러 그림 일기', '은해갑/깝치을', '아침형 뱀파이어', '공허에 잡아먹히다.', '두려움.증오.사랑', '7080 이야기', '가상현실 액션RPG', '작고 소중해', '전직 항해사 일기', '0229*', '정통 판타지 만화?', '능력자 판타지', '왈가닥냥과 같이살기', '가막의 문이 열렸다', '상중의 이상한 일상', '핥지마', '동물의 말이 들린다', '난임 정복 웹툰!', '新 무림 세계', '악몽 동화 이야기', '내 매력에 퐁당!', '코딩영재의 죽음', '내 눈앞에!', '로맨스 판타지', '자칭마녀와신비한소년', '빵집 알바 해봤니?', '초 자유연재 입니다', '아수라 죽이기', '육아 빙자 인생만화', '농촌 판타지 시트콤', '일상힐링툰', '보통의 경계', '극자본주의 액션!', '치유계 판타지', '단편만화', '맞춤형아파트프로젝트', '17살 선이의 나날', '유쾌한 친구들 얘기', '일상판타지 시대극', '쉼터 생활툰', '희망의 가치.', '댕댕이와의 일상:3', '이매인가, 망량인가', '초보집사와 초보주인', '귀염뽀짝 국제연애툰', '청부업자와 소년의 잔잔하고 슬픈 이야기', '사남매 가족 적응기', '시간여행판타지시대극', '초능력 소녀,그의 소유물이 되다', '강아지같은  사장', '솔직한 우리의 일상', '미대생의 삶', 'Z씨의 발버둥', '달집사와 봉츄냐옹이', '한국풍 저승 판타지', '우주에서 온 소녀들', '성우, 성장 로맨스', '태양계 일상', '세계가 우리 무대!', '알바생VS아이돌', '소프트BL', '돈이궁한 용병이야기', '인생은 혼자', '이세계에서 알바중', '달을 쫓는 소년', '일상이 스릴러', '바카랑호두랑도마뱀', '어딘지 학교가 익숙하지 않은 에밀리의 학교적응 이야기', '우주요원 제트', '아침 드라마형 좀비', '잠자던 공주 귀환기', '강동구씨의 이야기', '우리들의 상상이야기', '동양 판타지 서사극', '이과 발암만화', '사제님은 마족?', '수혁이 학원기', '광고감독의 웃픈일상', '현대판타지 스릴러', '정령왕들이 조잘조잘', '카페운영일상툰', '판타지', '전기수와 인방', '입시 미술하는 만화', '욕망 판타지', '판타지', ' ...
# ['8.57', '9.57', '9.90', '9.18', '9.85', '9.16', '9.89', '9.88', '9.87', '9.85', '9.84', '9.19', '9.68', '9.82', '9.90', '9.32', '9.77', '9.82', '9.87', '9.73', '9.82', '9.89', '9.70', '9.86', '9.60', '9.84', '9.77', '9.84', '9.55', '9.33', '9.65', '9.74', '9.65', '9.86', '9.55', '9.62', '9.78', '9.36', '9.85', '9.86', '9.72', '8.81', '9.81', '8.75', '9.86', '9.67', '9.49', '9.90', '9.66', '9.84', '9.67', '9.90', '9.59', '9.88', '9.86', '8.39', '9.01', '9.82', '9.89', '9.79', '9.74', '9.90', '9.90', '9.90', '9.65', '9.71', '9.25', '9.43', '9.68', '9.79', '9.66', '9.65', '9.82', '9.81', '9.76', '9.64', '9.58', '9.88', '9.78', '9.85', '9.03', '9.85', '9.55', '9.90', '9.37', '9.65', '9.45', '9.87', '9.75', '9.69', '7.45', '9.71', '9.62', '8.92', '9.86', '9.66', '9.30', '8.78', '8.73', '9.58', '9.47', '9.71', '9.89', '9.52', '9.89', '9.70', '9.62', '9.52', '9.33', '9.89', '7.63', '9.84', '9.58', '9.68', '9.81', '9.90', '9.89', '9.32', '9.84', '9.90', '9.41', '9.85', '9.19', '9.87', '9.86', '9.37', '9.57', '9.77', '9.70', '8.22', '9.66', '9.85', '9.87', '9.74', '9.36', '8.74', '9.30', '9.81', '8.05', '9.76', '9.14', '8.85', '9.60', '9.90', '9.77', '9.76', '9.90', '9.71', '9.14', '9.66', '9.47', '9.82', '9.71', '9.53', '9.82', '9.67', '9.90', '9.89', '8.64', '9.65', '9.84', '9.78', '9.90', '9.07', '9.47', '9.89', '9.86', '9.48', '9.78', '9.84', '9.70', '9.63', '9.79', '9.15', '9.86', '9.28', '9.89', '9.75', '9.89', '9.15', '9.53', '9.74', '9.83', '9.53', '9.86', '9.90', '9.86', '8.98', '9.87', '9.80', '9.78', '8.35', '8.96', '9.82', '9.61', '9.90', '9.83', '8.81', '9.89', '9.56', '9.71', '9.86', '9.78', '9.76', '9.87', '9.67', '9.66', '9.76', '9.89', '9.00', '9.64', '9.90', '9.88', '9.70', '9.53', '9.69', '9.76', '9.84', '9.89', '9.90', '9.83', '9.88', '9.90', '9.80', '9.65', '9.44', '9.74', '9.85', '9.44', '9.75', '9.51', '9.20', '9.90', '9.61', '9.86', '9.90', '9.90', '9.49', '9.63', '9.84', '9.85', '9.83', '9.89', '9.47', '9.05', '9.90', '9.73', '9.79', '9.09', '9.88', '9.59', '9.77', '9.53', '9.84', '9.87', '9.88', '9.57', '9.23', '9.54', '9.81', '9.86', '9.90', '9.42', '9.87', '9.90', '9.83', '9.78', '9.83', '9.90', '9.90', '9.76', '9.90', '9.78', '9.82', '9.80', '9.88', '9.90', '9.44', '9.75', '9.03', '9.86', '9.85', '9.90', '9.62', '9.86', '9.86', '9.90', '9.90', '9.84', '9.89', '9.61', '9.71', '9.78', '9.64', '7.85', '9.58', '9.70', '9.76', '9.25', '8.09', '9.67', '9.85', '9.87', '9.01', '9.76', '9.90', '9.90', '9.69', '9.78', '9.87', '9.84', '9.90', '7.73', '9.90', '9.51', '9.87', '9.90', '9.67', '9.84', '9.90', '9.84', '9.31', '9.36', '9.11', '9.80', '9.83', '9.83', '9.41', '9.83', '9.89', '9.61', '9.76', '9.90', '9.72', '9.90', '9.90', '9.40', '9.02', '9.80', '9.84', '9.76', '9.83', '9.87', '9.51', '9.84', '8.73', '9.16', '9.02', '9.68', '9.88', '9.72', '9.88', '9.07', '9.43', '9.13', '9.77', '9.81', '9.69', '9.33', '9.88', '9.89', '9.42', '9.41', '9.62', '9.25', '9.89', '9.55', '9.28', '8.50', '9.77', '9.90', '9.21', '9.86', '8.78', '9.80', '9.89', '9.87', '9.64', '9.87', '9.83', '9.11', '9.90', '9.88', '9.82', '9.87', '9.76', '9.82', '9.51', '9.76', '9.85', '9.87', '9.90', '9.77', '9.80', '9.88', '9.80', '9.75', '9.86', '9.90', '9.90', '9.74', '9.87', '9.86', '8.66', '9.90', '9.79', '9.72', '9.56', '9.63', '9.83', '9.89', '9.85', '9.87', '9.07', '9.85', '9.80', '9.36', '9.79', '9.89', '9.82', '9.79', '9.21', '9.86', '9.89', '9.86', '9.71', '9.90', '9.76', '9.72', '9.75', '9.82', '9.35', '9.46', '9.90', '9.09', '9.90', '9.73', '9.36', '9.68', '9.88', '9.21', '9.46', '9.66', '9.90', '9.74', '9.75', '9.88', '9.74', '9.71', '9.72', '9.89', '9.86', '9.87', '9.87', '9.88', '9.80', '9.74', '9.74', '9.69', '9.65', '9.85', '9.87', '9.83', '9.80', '9.89', '9.84', '9.90', '9.71', '8.45', '9.80', '9.58', '9.73', '9.90', '9.88', '9.84', '9.89', '9.26', '9.44', '9.90', '9.90', '9.90', '9.86', '9.67', '9.74', '9.44', '9.68', '9.85', '9.70', '9.87', '9.60', '9.90', '9.60', '9.68', '9.89', '9.77', '9.89', '9.86', '9.50', '9.87', '9.88', ...

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('p.goods_name.goods_icon > a > strong')
linklList = bs.select('p.goods_name.goods_icon > a')

for titleDom in titleList:
	title.append(titleDom.string)
for linkDom in linklList:
	link.append(linkDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('C:/Temp/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '핸즈온 머신러닝', '밑바닥부터 시작하는 딥러닝 ', '파이썬 알고리즘 인터뷰', '파이썬 for Beginner', '파이썬 증권 데이터 분석 ', '모두의 데이터 분석 with 파이썬', '파이썬 머신러닝 완벽 가이드', '밑바닥부터 시작하는 딥러닝 2', 'AWS 머신러닝 마스터하기', '생명정보학 알고리즘 ', 'Do it! 첫 파이썬', 'Do it! 점프 투 파이썬 + Do it! 첫 파이썬 ', 'Do it! 점프 투 파이썬 + 딥러닝 입문', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '모두의 인공지능 기초 수학', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916?OzSrank=1', '/Product/Goods/74269975?OzSrank=2', '/Product/Goods/91433923?OzSrank=3', '/Product/Goods/89959711?OzSrank=4', '/Product/Goods/34970929?OzSrank=5', '/Product/Goods/91084402?OzSrank=6', '/Product/Goods/83849188?OzSrank=7', '/Product/Goods/90578506?OzSrank=8', '/Product/Goods/72227684?OzSrank=9', '/Product/Goods/87044746?OzSrank=10', '/Product/Goods/72173703?OzSrank=11', '/Product/Goods/93737160?OzSrank=12', '/Product/Goods/93763052?OzSrank=13', '/Product/Goods/89904189?OzSrank=14', '/Product/Goods/91446188?OzSrank=15', '/Product/Goods/79672557?OzSrank=16', '/Product/Goods/91437485?OzSrank=17', '/Product/Goods/91446225?OzSrank=18', '/Product/Goods/91358533?OzSrank=19', '/Product/Goods/91219874?OzSrank=20']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser')

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')
# Out:
# {'서울': ['10~20', '10~20', '10~20', '10~20', '10~21', '10~21', '11~19', '11~19', '11~18', '11~18', '8~17', '7~18', '9~19'], '인천': ['11~19', '11~19', '12~19', '12~19', '11~19', '11~19', '13~19', '13~19', '13~18', '13~18', '9~17', '9~18', '10~18'], '수원': ['8~20', '8~20', '8~20', '8~20', '8~21', '8~21', '10~19', '10~19', '10~19', '10~19', '8~18', '6~19', '8~20'], '파주': ['5~19', '5~19', '6~20', '6~20', '5~20', '5~20', '7~19', '7~19', '7~19', '7~19', '6~19', '5~19', '5~19'], '이천': ['5~20', '5~20', '6~20', '6~20', '5~20', '5~20', '7~19', '7~19', '8~20', '8~20', '7~18', '6~19', '5~19'], '평택': ['7~20', '7~20', '8~20', '8~20', '7~20', '7~20', '9~20', '9~20', '10~19', '10~19', '9~18', '8~19', '8~20'], '춘천': ['5~20', '5~20', '6~20', '6~20', '6~20', '6~20', '8~17', '8~17', '10~18', '10~18', '5~15', '4~16', '6~17'], '원주': ['6~19', '6~19', '7~19', '7~19', '7~20', '7~20', '9~18', '9~18', '10~18', '10~18', '5~16', '4~17', '6~18'], '강릉': ['10~21', '10~21', '11~20', '11~20', '11~20', '11~20', '12~20', '12~20', '13~19', '13~19', '9~18', '9~17', '11~19'], '대전': ['8~20', '8~20', '9~21', '9~21', '8~21', '8~21', '11~19', '11~19', '11~20', '11~20', '8~18', '6~18', '9~19'], '세종': ['7~20', '7~20', '7~20', '7~20', '6~20', '6~20', '9~18', '9~18', '11~19', '11~19', '6~17', '5~18', '7~19'], '홍성': ['5~19', '5~19', '7~20', '7~20', '6~20', '6~20', '9~18', '9~18', '10~18', '10~18', '6~17', '5~18', '7~19'], '청주': ['8~20', '8~20', '9~20', '9~20', '8~21', '8~21', '11~19', '11~19', '12~19', '12~19', '8~18', '6~18', '9~19'], '충주': ['5~19', '5~19', '6~19', '6~19', '6~20', '6~20', '8~18', '8~18', '9~18', '9~18', '5~16', '4~17', '6~18'], '영동': ['4~21', '4~21', '6~20', '6~20', '5~21', '5~21', '8~19', '8~19', '10~18', '10~18', '5~17', '4~18', '6~19'], '광주': ['10~21', '10~21', '11~21', '11~21', '9~22', '9~22', '12~20', '12~20', '12~20', '12~20', '10~18', '8~19', '10~20'], '목포': ['11~20', '11~20', '13~20', '13~20', '11~21', '11~21', '13~20', '13~20', '14~20', '14~20', '12~18', '11~18', '12~20'], '여수': ['14~21', '14~21', '15~21', '15~21', '14~20', '14~20', '15~20', '15~20', '15~21', '15~21', '13~19', '12~19', '14~20'], '순천': ['10~22', '10~22', '12~23', '12~23', '9~23', '9~23', '13~21', '13~21', '13~21', '13~21', '10~19', '9~21', '11~21'], '광양': ['12~22', '12~22', '13~22', '13~22', '11~22', '11~22', '13~21', '13~21', '13~22', '13~22', '10~21', '9~20', '10~20'], '나주': ['7~22', '7~22', '9~22', '9~22', '6~22', '6~22', '10~21', '10~21', '11~20', '11~20', '8~18', '6~19', '9~20'], '전주': ['8~21', '8~21', '9~21', '9~21', '9~21', '9~21', '11~20', '11~20', '11~19', '11~19', '8~18', '7~19', '9~21'], '군산': ['8~20', '8~20', '9~20', '9~20', '9~21', '9~21', '11~19', '11~19', '11~20', '11~20', '8~18', '7~18', '9~19'], '정읍': ['8~20', '8~20', '9~21', '9~21', '9~21', '9~21', '10~19', '10~19', '10~20', '10~20', '7~18', '7~19', '8~20'], '남원': ['7~21', '7~21', '9~21', '9~21', '8~21', '8~21', '9~19', '9~19', '9~19', '9~19', '7~18', '6~19', '8~20'], '고창': ['8~21', '8~21', '9~21', '9~21', '9~21', '9~21', '10~20', '10~20', '10~20', '10~20', '8~17', '7~18', '8~19'], '무주': ['5~20', '5~20', '6~19', '6~19', '5~20', '5~20', '8~18', '8~18', '8~18', '8~18', '5~17', '4~17', '6~19'], '부산': ['13~22', '13~22', '14~22', '14~22', '13~22', '13~22', '15~22', '15~22', '15~22', '15~22', '12~20', '11~21', '13~22'], '울산': ['11~21', '11~21', '12~21', '12~21', '11~20', '11~20', '13~21', '13~21', '13~21', '13~21', '10~19', '9~19', '10~21'], '창원': ['11~21', '11~21', '12~21', '12~21', '11~21', '11~21', '13~21', '13~21', '14~22', '14~22', '11~19', '10~20', '12~22'], '진주': ['8~22', '8~22', '9~22', '9~22', '7~22', '7~22', '10~21', '10~21', '11~22', '11~22', '7~20', '6~20', '7~21'], '거창': ['5~21', '5~21', '6~21', '6~21', '5~21', '5~21', '8~19', '8~19', '9~20', '9~20', '5~18', '4~19', '5~20'], '통영': ['13~22', '13~22', '13~22', '13~22', '12~22', '12~22', '15~22', '15~22', '15~22', '15~22', '12~20', '11~20', '14~21'], '대구': ['8~21', '8~21', '10~21', '10~21', '8~22', '8~22', '11~20', '11~20', '13~21', '13~21', '8~19', '8~20', '9~20 ...

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
#page = data.decode('utf-8', 'ignore')
res_content = json.loads(data)

print(res_content["result"])
# Out:
# 브라우저 요청입니다.
