# %%
import requests
from bs4 import BeautifulSoup
title = []
name = []
urlstr = 'http://media.daum.net/ranking/popular/'
r = requests.get(urlstr)
r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('.rank_news>ul>li>.cont_thumb>strong>a')
nameList = bs.select(' div.cont_thumb > strong > span')

for titleDom in titleList:
	title.append(titleDom.string)
for nameDom in nameList:
	name.append(nameDom.string)

print('뉴스제목--------------')
print(title)
print(len(title))

print('뉴스이름--------------')
print(name)
print(len(name))

with open('C:/Temp/news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle,newscomname\n')  
    for i in range(len(title)):
        f.write('"'+title[i]+'",'+name[i]+'\n')
# Out:
# 뉴스제목--------------
# ["LA 상공에 다시 나타난 '아이언맨'..조종사들 증언 잇따라", '검찰 "동양대 표창장 위조 30초면 된다"..법정서 직접 시연', '국민의힘 "서울·부산시장 \'시민후보\'로"..\'미스터트롯\' 경선 준비(종합)', "'따상' 갔던 빅히트 미끄러지자..엔터株 '와르르'", "'거짓 미투' 피해 박진성 시인 극단 선택 암시하고 잠적", "시중에 풀린 돈 3100조 '사상 최대'..부동산·증시 거품 우려", '경비행기 추락사고서 엄마 품에 안긴 한살 아기만 살았다(종합)', '[최강시사] 유승준 변호사 "관광 비자 포함 어떤 비자로도 입국 불가능해, 테러리스트 아닌 이상 과도한 제한"', "'故 구하라 협박·폭행' 최종범 징역 1년 확정..불법촬영은 결국 무죄", '"걸그룹 시켜줄게" 미성년자 꼬드겨 음란행위 치과의사 징역 7년', '장윤정 "3년 전 이혼 후 중학생·고3 두 딸과 살고 있다"(\'같이 삽시다\')[종합]', '"김양식장에 사용하려고" 무기산 3만리터 산속 보관한 50대', '"펭수·뿡뿡이·보니하니 죄다 뺏겼습니다"..EBS 자회사 \'눈물\'', '"1만원 팔면 1500원은 카카오가 가져갑니다 ㅠㅠ" [IT선빵!]', '\'골목식당\' 최고 시청률 불러온 백종원 분노 "장사 너무 심하게 한다"', '보이스피싱에 속아 3000만원 갖고 부산 온 60대, 경찰이 예방', "개와 늑대의 잡종 '늑대개' 위험천만..미 2살배기 한쪽 팔 잃어", '진중권에 맞선 與 부대변인에 시선.."재담꾼 정치혐오 부추겨"', '1억 에르메스 vs 30만원 눈알가방..싸움의 끝은 화해', '정년퇴직 3년 앞두고 낡은 시골학교를 벽화로 채운 미술 선생님', '[D:방송 뷰] 싹쓰리에는 냉철했던 시선, 환불원정대는 다르다?', '"부르면 나간다"는 한동훈 증인채택 놓고 국감장 곳곳 설전', '김승현 \'불새2020\'으로 연기자 복귀 "최선 다할 것"(공식)', "17억 잠실엘스 산 10대, 63억 한남더힐 산 30대..'내돈내산' 맞나?", '11일간 먹지도 자지도 않고 날아간 흑꼬리도요 신기록 세웠다(종합)', "'보수단체 불법지원' 김기춘, 재상고 끝 징역 1년 확정(종합)", '추신수 떠난 텍사스, 김하성 영입 후보 "강정호보다 낫다"', '"열려있는 환자 뇌 사진 공개한 중앙의료원 의사 경징계 그쳐"', '바이든 67.5% vs 트럼프 32.8%.. 올들어 당선 확률 최대 격차', '사이클링히트 노리던 시거, 5회에 교체한 로버츠 감독 왜?', '"어느 시대냐" 日정부, 나카소네 전 총리 장례때 국립대 조기 계양, 묵념 요구 논란', "박정수 '카메라가 반갑지 않는 눈빛'[포토엔HD]", '서민 교수 "대깨문 압력에 지방강의 취소돼, 대깨문의 나라"', "보건교사 '심상정'이 국회에서 무지개칼을 휘두른 이유", '등산이 독이 되는 경우 5가지', '반년 만에 하늘길 뚫린 김해공항 국제선..첫날 승객들 "다행이에요"', "'빌런의 반격' 휴스턴, 탬파베이에 승리..최지만 1안타 [ALCS4]", "[단독] 박휘순♥17세 연하 예비신부, '아내의맛' 합류..결혼식 공개할까", '\'BBMAs\' 방탄소년단, 인천국제공항 무대→4년연속 수상 "아미 덕분"(종합)', '방시혁 주식재산 3.7조..정몽구 명예회장 이어 6위', '미스코리아 장윤정 "3년 전 이혼 후 정신없이 살았다" (\'같이 삽시다\') [엑\'s 리뷰]', 'TBS 김어준의 뉴스공장 편향성 논란..서정협 "공정성 담보 신경쓸 것"', '지적장애 딸 성폭행하고 "돌볼 사람없다"며 선처 호소한 아빠', '분당 9천400L 분사..미 소방로봇, LA 빌딩 화재 진압에 첫 투입', '"휴대전화 잃어버렸는데..\'토스\' 통해 150만원이 빠져나갔다"', '신규확진 110명..부산 요양병원 52명, 인천 주점 6명(종합2보)', "[월드리포트] 임진왜란 한 서린 '귀무덤'..일본인, 첫 위령제 올린다", "중국 누리꾼 'BTS 발언 지지했다가'..계정 삭제에 사과까지", "소금으로 '생태계 파괴자' 칡덩굴 없앤다..고사율 70.2%", '전미도 또 일 내나? \'보라빛 향기\' 리메이크 "윤상 프로듀싱 참여"']
# 50
# 뉴스이름--------------
# ['연합뉴스', '연합뉴스', '뉴스1', '뉴스1', '서울신문', '뉴시스', '연합뉴스', 'KBS', '뉴스1', '뉴스1', 'OSEN', '뉴스1', '한국경제', '헤럴드경제', '뉴스엔', '뉴시스', '연합뉴스', '연합뉴스', '머니투데이', '연합뉴스', '데일리안', '연합뉴스', '뉴스엔', '뉴스1', '연합뉴스', '연합뉴스', 'OSEN', '연합뉴스', '문화일보', 'OSEN', '중앙일보', '뉴스엔', '한국일보', '뉴스1', '코메디닷컴', '뉴스1', 'MK스포츠', '스포츠동아', '뉴스엔', '연합뉴스', '엑스포츠뉴스', '뉴시스', '뉴스1', '연합뉴스', '연합뉴스', '뉴스1', 'SBS', '연합뉴스', '연합뉴스', '뉴스엔']
# 50
